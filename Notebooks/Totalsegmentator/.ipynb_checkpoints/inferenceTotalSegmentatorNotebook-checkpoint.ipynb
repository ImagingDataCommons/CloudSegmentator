# %% [markdown]
# <a href="https://colab.research.google.com/github/ImagingDataCommons/Cloud-Resources-Workflows/blob/main/Notebooks/Totalsegmentator/inferenceTotalSegmentatorNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**This Notebook performs inference using TotalSegmentator (v1.5.5) with CT NIfTI file as input and produces multilabel Segmentation Maps NIfTI file**

# %% [markdown]
# Please cite:
#
# Jakob Wasserthal, Manfred Meyer, Hanns-Christian Breit, Joshy Cyriac, Shan Yang, & Martin Segeroth. (2022). TotalSegmentator: robust segmentation of 104 anatomical structures in CT images. https://doi.org/10.48550/arXiv.2208.05868
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nat Methods 18, 203–211 (2021). https://doi.org/10.1038/s41592-020-01008-z

# %% [markdown]
# ![notebook figures.png](data:image/png;base64,...)

# %% [markdown]
# Expected file directory
# ```
# dcm2niix
#  └─── $series_id_1
#        ├─── $CT_NIfTI.nii.gz
#        │
#  └───  $series_id_2
#        ├─── $CT_NIfTI.nii.gz
#        ├───  ...
#        │
#  └───  $series_id_n
#        └─── $CT_NIfTI.nii.gz
#
# ```

# %% [markdown]
# ##**Ways to utilize this notebook**
#
#
# *   **Colab**
# *   **Jupyter Notebook/Lab**
# *   **DockerContainer/Terra/SB-CGC**
#
#
# ####**Colab/JupyterNotebook/JupyterLab**
# *  This notebook was initally developed and tested on Colab, and a working version is saved on github
# *  To run this notebook with Colab, Click 'Open In Colab' icon on top left ![image.png](data:image/png;base64,...)
# *Uncomment all the cells under "Installing Packages"
# *Provide the path to lz4 compressed file containing CT NIfTI files as shown 'Expected file directory' under "Parameters for Papermill"
# * A sample lz4 file is provided for convenience can be downloaded by uncommenting and running the cells in "For local testing"
# * Run each cell to install the packages and to run the inference using TotalSegmentator and the segmentation maps in NIfTI format are saved in lz4 compressed format
#
#
# ####**Docker**
# * This notebook is saved by default in a way that's amenable to be used on Terra/SB-CGC platforms using Docker
# * Running this notebook in a docker container ensures reproduciblity, as we lock the run environment beginning from the base docker image to apt packages and pip packages in the docker image
#
# * Docker images can be found @ https://hub.docker.com/repository/docker/imagingdatacommons/inference_totalseg/tags
# * The link to dockerfile along with git commit hash used for building the docker image can be found in one of the layers called 'LABEL'
#
# ![image.png](data:image/png;base64,...)
# * We use a python package called Papermill, that can run the notebook with out having to convert it to python script. This allows us maintain one copy of code instead of two.
# * To use papermill, download this notebook and tag the cell under 'Parameters for Papermill" as parameters using jupyternotebook or jupyterlab as instructed @ https://papermill.readthedocs.io/en/latest/usage-parameterize.html#designate-parameters-for-a-cell
# * A sample papermill command is
# <pre>
# papermill -p niftiFilePath path_to_ct_nifti_files.lz4 inferenceTotalSegmentatorNotebook.ipynb.ipynb  output_inferenceTotalSegmentatorNotebook.ipynb
# </pre>

# %% [markdown]
# ###**Installing Packages**

# %%
# # %%capture
# !sudo apt-get update && apt-get install -y --no-install-recommends \
#     build-essential\
#     ffmpeg\
#     lz4\
#     python3-dev\
#     python3-pip\
#     wget\
#     unzip\
#     xvfb\
#   && rm -rf /var/lib/apt/lists/*
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [515 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [49.9 kB]
# Hit:9 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,283 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,158 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,260 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [28.1 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [50.4 kB]
# Get:15 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:16 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:17 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:18 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [21.8 kB]
# Fetched 4,728 kB in 3s (1,430 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# wget is already the newest version (1.21.2-2ubuntu1).
# python3-dev is already the newest version (3.10.6-1~22.04).
# python3-dev set to manually installed.
# unzip is already the newest version (6.0-26ubuntu3.1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 python3-setuptools python3-wheel
#   x11-xkb-utils xserver-common
# Suggested packages:
#   python-setuptools-doc
# Recommended packages:
#   xfonts-base
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 lz4 python3-pip python3-setuptools
#   python3-wheel x11-xkb-utils xserver-common xvfb
# 0 upgraded, 10 newly installed, 0 to remove and 19 not upgraded.
# Need to get 3,011 kB of archives.
# After this operation, 12.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 lz4 amd64 1.9.3-2build2 [90.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-setuptools all 59.6.0-1.2ubuntu0.22.04.1 [339 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel all 0.37.1-2ubuntu0.22.04.1 [32.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip all 22.0.2+dfsg-1ubuntu0.3 [1,305 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.1 [28.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.1 [863 kB]
# Fetched 3,011 kB in 1s (3,190 kB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 120895 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package lz4.
# Preparing to unpack .../3-lz4_1.9.3-2build2_amd64.deb ...
# Unpacking lz4 (1.9.3-2build2) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../4-python3-setuptools_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../5-python3-wheel_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../6-python3-pip_22.0.2+dfsg-1ubuntu0.3_all.deb ...
# Unpacking python3-pip (22.0.2+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../7-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../8-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.1_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.1) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../9-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.1_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.1) ...
# Setting up python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up python3-pip (22.0.2+dfsg-1ubuntu0.3) ...
# Setting up lz4 (1.9.3-2build2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.1) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link

# %%
# # %%capture
# !pip install --no-cache-dir \
#     ipykernel==6.22.0\
#     ipython==8.12.0\
#     ipywidgets==8.0.6\
#     jupyter==1.0.0\
#     papermill==2.4.0\
#     nvidia-ml-py3==7.352.0\
#     TotalSegmentator==1.5.5\
#  && pip install --no-cache-dir \
#     pyradiomics==3.0.1
# Out:
# Collecting ipykernel==6.22.0
#   Downloading ipykernel-6.22.0-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.0/150.0 kB 4.0 MB/s eta 0:00:00
# Collecting ipython==8.12.0
#   Downloading ipython-8.12.0-py3-none-any.whl (796 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.4/796.4 kB 16.6 MB/s eta 0:00:00
# Collecting ipywidgets==8.0.6
#   Downloading ipywidgets-8.0.6-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 28.2 MB/s eta 0:00:00
# Collecting jupyter==1.0.0
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting papermill==2.4.0
#   Downloading papermill-2.4.0-py3-none-any.whl (38 kB)
# Collecting nvidia-ml-py3==7.352.0
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting TotalSegmentator==1.5.5
#   Downloading TotalSegmentator-1.5.5-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 191.1 MB/s eta 0:00:00
# Collecting comm>=0.1.1 (from ipykernel==6.22.0)
#   Downloading comm-0.1.4-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.22.0) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.22.0) (6.1.12)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.22.0) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.22.0) (0.1.6)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.22.0) (1.5.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.22.0) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.22.0) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.22.0) (23.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.22.0) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel==6.22.0) (5.7.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0) (4.4.2)
# Collecting jedi>=0.16 (from ipython==8.12.0)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.1 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0) (2.16.1)
# Collecting stack-data (from ipython==8.12.0)
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython==8.12.0) (4.8.0)
# Collecting widgetsnbextension~=4.0.7 (from ipywidgets==8.0.6)
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 34.6 MB/s eta 0:00:00
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.0.6) (3.0.8)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0) (6.5.5)
# Collecting qtconsole (from jupyter==1.0.0)
#   Downloading qtconsole-5.4.4-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 343.0 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0) (6.5.4)
# Collecting ansiwrap (from papermill==2.4.0)
#   Downloading ansiwrap-0.8.4-py2.py3-none-any.whl (8.5 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from papermill==2.4.0) (8.1.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from papermill==2.4.0) (6.0.1)
# Requirement already satisfied: nbformat>=5.1.2 in /usr/local/lib/python3.10/dist-packages (from papermill==2.4.0) (5.9.2)
# Requirement already satisfied: nbclient>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from papermill==2.4.0) (0.8.0)
# Requirement already satisfied: tqdm>=4.32.2 in /usr/local/lib/python3.10/dist-packages (from papermill==2.4.0) (4.66.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from papermill==2.4.0) (2.31.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from papermill==2.4.0) (0.4)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from papermill==2.4.0) (8.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from TotalSegmentator==1.5.5) (1.23.5)
# Collecting SimpleITK (from TotalSegmentator==1.5.5)
#   Downloading SimpleITK-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 124.6 MB/s eta 0:00:00
# Requirement already satisfied: nibabel>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from TotalSegmentator==1.5.5) (4.0.2)
# Collecting p-tqdm (from TotalSegmentator==1.5.5)
#   Downloading p_tqdm-1.4.0.tar.gz (5.2 kB)
#   Preparing metadata (setup.py) ... done
# Collecting xvfbwrapper (from TotalSegmentator==1.5.5)
#   Downloading xvfbwrapper-0.2.9.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fury (from TotalSegmentator==1.5.5)
#   Downloading fury-0.9.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.8/510.8 kB 391.8 MB/s eta 0:00:00
# Collecting batchgenerators==0.21 (from TotalSegmentator==1.5.5)
#   Downloading batchgenerators-0.21-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 290.4 MB/s eta 0:00:00
# Collecting nnunet-customized==1.2 (from TotalSegmentator==1.5.5)
#   Downloading nnunet_customized-1.2-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.0/474.0 kB 359.6 MB/s eta 0:00:00
# Collecting rt-utils (from TotalSegmentator==1.5.5)
#   Downloading rt_utils-1.2.7-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from batchgenerators==0.21->TotalSegmentator==1.5.5) (9.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from batchgenerators==0.21->TotalSegmentator==1.5.5) (1.11.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from batchgenerators==0.21->TotalSegmentator==1.5.5) (0.19.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from batchgenerators==0.21->TotalSegmentator==1.5.5) (1.2.2)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from batchgenerators==0.21->TotalSegmentator==1.5.5) (0.18.3)
# Collecting unittest2 (from batchgenerators==0.21->TotalSegmentator==1.5.5)
#   Downloading unittest2-1.1.0-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 276.5 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.10/dist-packages (from batchgenerators==0.21->TotalSegmentator==1.5.5) (3.2.0)
# Requirement already satisfied: torch>=1.6.0a in /usr/local/lib/python3.10/dist-packages (from nnunet-customized==1.2->TotalSegmentator==1.5.5) (2.0.1+cu118)
# Collecting dicom2nifti (from nnunet-customized==1.2->TotalSegmentator==1.5.5)
#   Downloading dicom2nifti-2.4.8-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 190.6 MB/s eta 0:00:00
# Collecting medpy (from nnunet-customized==1.2->TotalSegmentator==1.5.5)
#   Downloading MedPy-0.4.0.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.8/151.8 kB 329.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nnunet-customized==1.2->TotalSegmentator==1.5.5) (1.5.3)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.10/dist-packages (from nnunet-customized==1.2->TotalSegmentator==1.5.5) (2023.8.30)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython==8.12.0) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->ipykernel==6.22.0) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.22.0) (3.10.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1.2->papermill==2.4.0) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1.2->papermill==2.4.0) (4.19.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel>=2.3.0->TotalSegmentator==1.5.5) (67.7.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython==8.12.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.12.0) (0.2.6)
# Collecting textwrap3>=0.9.2 (from ansiwrap->papermill==2.4.0)
#   Downloading textwrap3-0.9.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: aiohttp>=3.8.4 in /usr/local/lib/python3.10/dist-packages (from fury->TotalSegmentator==1.5.5) (3.8.5)
# Collecting pygltflib>=1.15.3 (from fury->TotalSegmentator==1.5.5)
#   Downloading pygltflib-1.16.0.tar.gz (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 236.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting vtk>=9.1.0 (from fury->TotalSegmentator==1.5.5)
#   Downloading vtk-9.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (79.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 MB 142.4 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0) (1.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0) (23.1.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0) (1.0.0)
# Collecting pathos>=0.2.5 (from p-tqdm->TotalSegmentator==1.5.5)
#   Downloading pathos-0.3.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 311.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from p-tqdm->TotalSegmentator==1.5.5) (1.16.0)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter==1.0.0)
#   Downloading QtPy-2.4.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 kB 277.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->papermill==2.4.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->papermill==2.4.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->papermill==2.4.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->papermill==2.4.0) (2023.7.22)
# Collecting pydicom (from rt-utils->TotalSegmentator==1.5.5)
#   Downloading pydicom-2.4.3-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 254.5 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from rt-utils->TotalSegmentator==1.5.5) (4.8.0.76)
# Collecting dataclasses (from rt-utils->TotalSegmentator==1.5.5)
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting executing>=1.2.0 (from stack-data->ipython==8.12.0)
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython==8.12.0)
#   Downloading asttokens-2.4.0-py2.py3-none-any.whl (27 kB)
# Collecting pure-eval (from stack-data->ipython==8.12.0)
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->fury->TotalSegmentator==1.5.5) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->fury->TotalSegmentator==1.5.5) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->fury->TotalSegmentator==1.5.5) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->fury->TotalSegmentator==1.5.5) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->fury->TotalSegmentator==1.5.5) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8.4->fury->TotalSegmentator==1.5.5) (1.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.4.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.4.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.4.0) (0.10.2)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter==1.0.0) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter==1.0.0) (0.2.3)
# Collecting ppft>=1.7.6.7 (from pathos>=0.2.5->p-tqdm->TotalSegmentator==1.5.5)
#   Downloading ppft-1.7.6.7-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 286.6 MB/s eta 0:00:00
# Collecting dill>=0.3.7 (from pathos>=0.2.5->p-tqdm->TotalSegmentator==1.5.5)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 283.9 MB/s eta 0:00:00
# Collecting pox>=0.3.3 (from pathos>=0.2.5->p-tqdm->TotalSegmentator==1.5.5)
#   Downloading pox-0.3.3-py3-none-any.whl (29 kB)
# Collecting multiprocess>=0.70.15 (from pathos>=0.2.5->p-tqdm->TotalSegmentator==1.5.5)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 351.9 MB/s eta 0:00:00
# Collecting dataclasses-json>=0.0.25 (from pygltflib>=1.15.3->fury->TotalSegmentator==1.5.5)
#   Downloading dataclasses_json-0.6.0-py3-none-any.whl (27 kB)
# Collecting deprecated (from pygltflib>=1.15.3->fury->TotalSegmentator==1.5.5)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->batchgenerators==0.21->TotalSegmentator==1.5.5) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->batchgenerators==0.21->TotalSegmentator==1.5.5) (2.31.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->batchgenerators==0.21->TotalSegmentator==1.5.5) (1.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0a->nnunet-customized==1.2->TotalSegmentator==1.5.5) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0a->nnunet-customized==1.2->TotalSegmentator==1.5.5) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0a->nnunet-customized==1.2->TotalSegmentator==1.5.5) (1.12)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0a->nnunet-customized==1.2->TotalSegmentator==1.5.5) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0a->nnunet-customized==1.2->TotalSegmentator==1.5.5) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0a->nnunet-customized==1.2->TotalSegmentator==1.5.5) (16.0.6)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from vtk>=9.1.0->fury->TotalSegmentator==1.5.5) (3.7.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter==1.0.0) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter==1.0.0) (0.5.1)
# Collecting python-gdcm (from dicom2nifti->nnunet-customized==1.2->TotalSegmentator==1.5.5)
#   Downloading python_gdcm-3.0.22-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 62.8 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nnunet-customized==1.2->TotalSegmentator==1.5.5) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->batchgenerators==0.21->TotalSegmentator==1.5.5) (1.3.2)
# Collecting argparse (from unittest2->batchgenerators==0.21->TotalSegmentator==1.5.5)
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Collecting traceback2 (from unittest2->batchgenerators==0.21->TotalSegmentator==1.5.5)
#   Downloading traceback2-1.4.0-py2.py3-none-any.whl (16 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json>=0.0.25->pygltflib>=1.15.3->fury->TotalSegmentator==1.5.5)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 255.9 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json>=0.0.25->pygltflib>=1.15.3->fury->TotalSegmentator==1.5.5)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (1.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk>=9.1.0->fury->TotalSegmentator==1.5.5) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk>=9.1.0->fury->TotalSegmentator==1.5.5) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk>=9.1.0->fury->TotalSegmentator==1.5.5) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk>=9.1.0->fury->TotalSegmentator==1.5.5) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk>=9.1.0->fury->TotalSegmentator==1.5.5) (3.1.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0) (1.15.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->pygltflib>=1.15.3->fury->TotalSegmentator==1.5.5) (1.15.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0a->nnunet-customized==1.2->TotalSegmentator==1.5.5) (1.3.0)
# Collecting linecache2 (from traceback2->unittest2->batchgenerators==0.21->TotalSegmentator==1.5.5)
#   Downloading linecache2-1.0.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter==1.0.0) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0) (2.21)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.0.25->pygltflib>=1.15.3->fury->TotalSegmentator==1.5.5)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: nvidia-ml-py3, p-tqdm, xvfbwrapper, pygltflib, medpy
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19171 sha256=b9bba9cf2d3197d52f29e5069ba798ace9af98c8248fb11d9d45b420bb5ddb06
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c2r11e_9/wheels/5c/d8/c0/46899f8be7a75a2ffd197a23c8797700ea858b9b34819fbf9e
#   Building wheel for p-tqdm (setup.py) ... done
#   Created wheel for p-tqdm: filename=p_tqdm-1.4.0-py3-none-any.whl size=5380 sha256=0ffe54f4bde0670265e5d07911ae9ae9b227d135af4c26675e48d002e25dd071
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c2r11e_9/wheels/8e/f1/4b/e9e4adb8e573e9c41176bc7a08c47bba6babedc75900f5d05e
#   Building wheel for xvfbwrapper (setup.py) ... done
#   Created wheel for xvfbwrapper: filename=xvfbwrapper-0.2.9-py3-none-any.whl size=5009 sha256=7cb051b3ffdc420b4300ec360f54befd4166c307b422bda20f145c679b35a271
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c2r11e_9/wheels/cb/10/7d/2b7fdffccf837f7d5425931575fbee9caebe2c190931f9058b
#   Building wheel for pygltflib (setup.py) ... done
#   Created wheel for pygltflib: filename=pygltflib-1.16.0-py3-none-any.whl size=26737 sha256=2dbf4dc96c31661a3176a344187cfe0994d7edbc45a2c8926c319f3340febfc6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c2r11e_9/wheels/c3/1d/50/8617405c77a1e3dc5a26d683b90111b00e86098880cac5f13b
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-py3-none-any.whl size=214949 sha256=434016676712cba3b986198954e29525436cf5ad8b84ab6b278b35631040bf64
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c2r11e_9/wheels/d4/32/c7/6380ab2edb8cca018d39a0f1d43250fd9791922c963117de46
# Successfully built nvidia-ml-py3 p-tqdm xvfbwrapper pygltflib medpy
# Installing collected packages: xvfbwrapper, textwrap3, SimpleITK, pure-eval, nvidia-ml-py3, linecache2, executing, dataclasses, argparse, widgetsnbextension, traceback2, qtpy, python-gdcm, pydicom, ppft, pox, mypy-extensions, marshmallow, jedi, dill, deprecated, comm, asttokens, ansiwrap, unittest2, typing-inspect, stack-data, rt-utils, multiprocess, medpy, dicom2nifti, vtk, pathos, ipython, dataclasses-json, batchgenerators, pygltflib, p-tqdm, ipykernel, qtconsole, ipywidgets, fury, papermill, jupyter, nnunet-customized, TotalSegmentator
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.5
#     Uninstalling widgetsnbextension-3.6.5:
#       Successfully uninstalled widgetsnbextension-3.6.5
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==5.5.6, but you have ipykernel 6.22.0 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.12.0 which is incompatible.
# Successfully installed SimpleITK-2.3.0 TotalSegmentator-1.5.5 ansiwrap-0.8.4 argparse-1.4.0 asttokens-2.4.0 batchgenerators-0.21 comm-0.1.4 dataclasses-0.6 dataclasses-json-0.6.0 deprecated-1.2.14 dicom2nifti-2.4.8 dill-0.3.7 executing-1.2.0 fury-0.9.0 ipykernel-6.22.0 ipython-8.12.0 ipywidgets-8.0.6 jedi-0.19.0 jupyter-1.0.0 linecache2-1.0.0 marshmallow-3.20.1 medpy-0.4.0 multiprocess-0.70.15 mypy-extensions-1.0.0 nnunet-customized-1.2 nvidia-ml-py3-7.352.0 p-tqdm-1.4.0 papermill-2.4.0 pathos-0.3.1 pox-0.3.3 ppft-1.7.6.7 pure-eval-0.2.2 pydicom-2.4.3 pygltflib-1.16.0 python-gdcm-3.0.22 qtconsole-5.4.4 qtpy-2.4.0 rt-utils-1.2.7 stack-data-0.6.2 textwrap3-0.9.2 traceback2-1.4.0 typing-inspect-0.9.0 unittest2-1.1.0 vtk-9.2.6 widgetsnbextension-4.0.9 xvfbwrapper-0.2.9
# Collecting pyradiomics==3.0.1
#   Downloading pyradiomics-3.0.1.tar.gz (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from pyradiomics==3.0.1) (1.23.5)
# Requirement already satisfied: SimpleITK>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from pyradiomics==3.0.1) (2.3.0)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pyradiomics==3.0.1) (1.4.1)
# Collecting pykwalify>=1.6.0 (from pyradiomics==3.0.1)
#   Downloading pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from pyradiomics==3.0.1) (1.16.0)
# Collecting docopt>=0.6.2 (from pykwalify>=1.6.0->pyradiomics==3.0.1)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from pykwalify>=1.6.0->pyradiomics==3.0.1) (2.8.2)
# Collecting ruamel.yaml>=0.16.0 (from pykwalify>=1.6.0->pyradiomics==3.0.1)
#   Downloading ruamel.yaml-0.17.32-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 298.4 MB/s eta 0:00:00
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.16.0->pykwalify>=1.6.0->pyradiomics==3.0.1)
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 198.7 MB/s eta 0:00:00
# Building wheels for collected packages: pyradiomics, docopt
#   Building wheel for pyradiomics (setup.py) ... done
#   Created wheel for pyradiomics: filename=pyradiomics-3.0.1-cp310-cp310-linux_x86_64.whl size=169718 sha256=854f03cb39d5c7d14ec0959826ecaab46d0934577ed54bcbbafd55765828c366
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ftd06950/wheels/91/c5/13/c5fd4c5ad3edf4062bb3855bd66fad25871c9c6dc0b3fda544
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=8ecfd0a2778c9e999702de2308b7056e8a3be08577b1f8f4472b3848a2e85155
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ftd06950/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built pyradiomics docopt
# Installing collected packages: docopt, ruamel.yaml.clib, ruamel.yaml, pykwalify, pyradiomics
# Successfully installed docopt-0.6.2 pykwalify-1.8.0 pyradiomics-3.0.1 ruamel.yaml-0.17.32 ruamel.yaml.clib-0.2.7

# %% [markdown]
# ###**Importing Packages**

# %%
import glob
import os
import sys
import shutil
from pathlib import Path
import time
import subprocess
from concurrent.futures import ThreadPoolExecutor
from time import sleep
from datetime import datetime
import psutil
import pandas as pd
import matplotlib.pyplot as plt
import nvidia_smi

curr_dir   = Path().absolute()

print(time.asctime(time.localtime()))
print("\nCurrent directory :{}".format( curr_dir))
print("Python version    :", sys.version.split('\n')[0])
# Out:
# Mon Sep 25 22:04:42 2023
#
# Current directory :/content
# Python version    : 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]

# %% [markdown]
# ###**Parameters for Papermill**

# %%
niftiFilePath=''

# %% [markdown]
# ###**Environment Variable**

# %%
converterType='dcm2niix'

# %% [markdown]
# ###**Local testing**

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown "https://drive.google.com/uc?id=1LsRPn_gTWUwVZwrcnSllogTaw8MW2d2M"
# niftiFilePath= glob.glob("*.lz4")[0]
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LsRPn_gTWUwVZwrcnSllogTaw8MW2d2M
# To: /content/_1_downloadDicomAndConvertNiftiFiles.tar.lz4
# 100% 464M/464M [00:07<00:00, 60.0MB/s]

# %% [markdown]
# ###**Decompressing NIFTI files from first step**

# %%
# !lz4 -d --rm {niftiFilePath} -c | tar  --strip-components=0  -xvf -
# Out:
# dcm2niix/
# dcm2niix/1.3.6.1.4.1.14519.5.2.1.7009.9004.118722452529394350711166589345/
# dcm2niix/1.3.6.1.4.1.14519.5.2.1.7009.9004.118722452529394350711166589345/1.3.6.1.4.1.14519.5.2.1.7009.9004.11872245252939435071116658934_1_OPA_GE_LSPR16_STANDARD_330_2.5_120_80_58.2_1.4_20000102000000_2.nii.gz
# dcm2niix/1.3.6.1.4.1.14519.5.2.1.7009.9004.431377773401197924485551006033/
# dcm2niix/1.3.6.1.4.1.14519.5.2.1.7009.9004.431377773401197924485551006033/1.3.6.1.4.1.14519.5.2.1.7009.9004.43137777340119792448555100603_1_OPA_GE_LS16_STANDARD_339_2.5_120_40_29.1_1.4_20000102000000_2.nii.gz
# dcm2niix/1.2.840.113654.2.55.100875189782210690344207306235124901243/
# dcm2niix/1.2.840.113654.2.55.100875189782210690344207306235124901243/1.2.840.113654.2.55.100875189782210690344207306235124901243_0_OPA_GE_LSQX_STANDARD_360_2.5_120_na_na_na_19990102000000_2.nii.gz
# dcm2niix/1.2.840.113654.2.55.113040386178547843571271236478024341696/
# dcm2niix/1.2.840.113654.2.55.113040386178547843571271236478024341696/1.2.840.113654.2.55.113040386178547843571271236478024341696_0_OPA_GE_LSQX_STANDARD_352_2.5_120_64_0.1_1.5_19990102000000_2.nii.gz
# dcm2niix/1.2.840.113654.2.55.142419057730651121165090739113900499978/
# dcm2niix/1.2.840.113654.2.55.142419057730651121165090739113900499978/1.2.840.113654.2.55.142419057730651121165090739113900499978_2_OPA_GE_LSQX_BONE_360_2.5_120_72_0.1_1.5_20010102000000_3.nii.gz
# dcm2niix/1.2.840.113654.2.55.14382674871619950799472325766084940706/
# dcm2niix/1.2.840.113654.2.55.14382674871619950799472325766084940706/1.2.840.113654.2.55.14382674871619950799472325766084940706_0_OPA_GE_LSQX_STANDARD_350_2.5_120_na_na_na_19990102000000_2.nii.gz
# dcm2niix/1.2.840.113654.2.55.146601594654322994982630019583270053397/
# dcm2niix/1.2.840.113654.2.55.146601594654322994982630019583270053397/1.2.840.113654.2.55.146601594654322994982630019583270053397_1_OPA_GE_LSQX_STANDARD_360_2.5_140_40_0_1.5_20000102000000_2.nii.gz
# dcm2niix/1.2.840.113654.2.55.154809705591242159075253605419469935510/
# dcm2niix/1.2.840.113654.2.55.154809705591242159075253605419469935510/1.2.840.113654.2.55.154809705591242159075253605419469935510_0_OPA_GE_LSQX_STANDARD_310_2.5_120_64_0.1_1.5_19990102000000_2.nii.gz
# dcm2niix/1.2.840.113654.2.55.185309182591805634517860395342326800332/
# dcm2niix/1.2.840.113654.2.55.185309182591805634517860395342326800332/1.2.840.113654.2.55.185309182591805634517860395342326800332_1_OPA_GE_LSQX_STANDARD_360_2.5_120_48_0_1.5_20000102000000_2.nii.gz
# dcm2niix/1.2.840.113654.2.55.216614002338888733987350522981366678482/
# dcm2niix/1.2.840.113654.2.55.216614002338888733987350522981366678482/1.2.840.113654.2.55.216614002338888733987350522981366678482_0_OPA_GE_HSQX_BONE_340_2.5_120_56_0.1_1.5_19990102000000_3.nii.gz
# dcm2niix/1.2.840.113654.2.55.22770087029972268579113866309746562015/
# dcm2niix/1.2.840.113654.2.55.22770087029972268579113866309746562015/1.2.840.113654.2.55.22770087029972268579113866309746562015_1_OPA_GE_HSQX_STANDARD_380_2.5_120_56_0.1_1.5_20000102000000_2.nii.gz
# dcm2niix/1.2.840.113654.2.55.243990451406006403331425809632881193215/
# dcm2niix/1.2.840.113654.2.55.243990451406006403331425809632881193215/1.2.840.113654.2.55.243990451406006403331425809632881193215_1_OPA_GE_LSQX_STANDARD_360_2.5_120_64_0.1_1.5_20000102000000_2.nii.gz

# %% [markdown]
# ###**Defining Functions**

# %%
#create directory for TotalSegmentator Output files
try:
  shutil.rmtree('Inference')

except OSError:
  pass
os.mkdir('Inference')

# %%
class MemoryMonitor:
    def __init__(self):
        self.keep_measuring = True
        self.working_disk_path = self.get_working_disk_path()

    def get_working_disk_path(self):
        partitions = psutil.disk_partitions()
        for partition in partitions:
            if partition.mountpoint == '/':
                return '/'
            elif '/cromwell_root' in partition.mountpoint:
                return '/cromwell_root'
        return '/'  # Default to root directory if no specific path is found
    def measure_usage(self):
        cpu_usage = []
        ram_usage_mb=[]
        gpu_usage_mb=[]
        disk_usage_all=[]
        time_stamps = []
        start_time = time.time()
        while self.keep_measuring:
            cpu = psutil.cpu_percent()
            ram = psutil.virtual_memory()
            disk_usage = psutil.disk_usage(self.working_disk_path)
            disk_used = disk_usage.used / 1024 / 1024 / 1024
            disk_total = disk_usage.total / 1024 / 1024 / 1024
            ram_total_mb = psutil.virtual_memory().total / 1024 / 1024
            ram_mb = (ram.total - ram.available) / 1024 / 1024

            nvidia_smi.nvmlInit()
            handle = nvidia_smi.nvmlDeviceGetHandleByIndex(0)
            info = nvidia_smi.nvmlDeviceGetMemoryInfo(handle)
            gpu_type = nvidia_smi.nvmlDeviceGetName(handle)
            gpu_total_mb = info.total/1024/1024
            gpu_mb = info.used/1024/1024
            nvidia_smi.nvmlShutdown()

            cpu_usage.append(cpu)
            ram_usage_mb.append(ram_mb)
            disk_usage_all.append(disk_used)
            gpu_usage_mb.append(gpu_mb)
            time_stamps.append(time.time()- start_time)
            sleep(1)

        return cpu_usage, ram_usage_mb, time_stamps, ram_total_mb, gpu_usage_mb, gpu_total_mb, gpu_type, disk_usage_all, disk_total

# %%
def check_total_segmentator_errors(series_id: str):
  """
  This function checks if the output files from TotalSegmentator exist.

  Args:
  series_id (str): The DICOM Tag SeriesInstanceUID of the DICOM series to be checked.

  Returns:
  bool: True if any of the output files do not exist, False otherwise.
  """

  # Define the output files from TotalSegmentator
  output_files = [f"{curr_dir}/Inference/{series_id}/segmentations.nii"]

  # Check if all output files exist
  if not all(os.path.exists(file) for file in output_files):
      # If any of the output files do not exist, log an error
      with open('totalsegmentator_errors.txt', 'a') as f:
          f.write(f"Error: TotalSegmentator failed for series {series_id}\n")
      return True

  return False

# %%
def inferenceTotalSegmentator(series_id: str) -> None:
    """
    This function performs inference using TotalSegmentator on a given series.

    Args:
    series_id (str): The DICOM Tag SeriesInstanceUID of the DICOM series to be processed.
    """

    # Remove existing directories and files if they exist
    shutil.rmtree(f'Inference/{series_id}', ignore_errors=True)
    shutil.rmtree(f'metadata/{series_id}', ignore_errors=True)
    for file in ['segmentations.nii.gz']:
        try:
            os.remove(file)
        except OSError:
            pass

    # Create a new directory for the series
    os.makedirs(f'Inference/{series_id}', exist_ok=True)

    print(f"Processing series: {series_id}")

    log = pd.DataFrame({'SeriesInstanceUID': [series_id]})
    series_id_folder_path = os.path.join(curr_dir, converterType, series_id)

    # Get the first (and only) file in the list
    nifti_filename = os.listdir(series_id_folder_path)[0]
    nifti_filename_path = os.path.join(series_id_folder_path, nifti_filename)

    start_time = time.time()
    result = subprocess.run(['TotalSegmentator', '-i', nifti_filename_path, '-o', 'segmentations', '--ml'], stdout=subprocess.PIPE, stderr=subprocess.PIPE,  universal_newlines=True)
    print(result.stdout)
    total_segmentator_time = time.time() - start_time

    # Move the output files to the appropriate directory
    try:
        shutil.move(f"{curr_dir}/segmentations.nii", f"{curr_dir}/Inference/{series_id}/")
        print("Files moved successfully using the first command")
    except FileNotFoundError:
        try:
            shutil.move("segmentations/segmentations.nii", f"{curr_dir}/Inference/{series_id}/")
            print("Files moved successfully using the second command")
        except FileNotFoundError:
            print("Error: Failed to move files using both commands")


    check_total_segmentator_errors(series_id)

    shutil.move(f"{curr_dir}/Inference/{series_id}/segmentations.nii", f"{curr_dir}/Inference/{series_id}/{series_id}.nii")

    start_time = time.time()
    subprocess.run(["lz4", "--rm", f"{curr_dir}/Inference/{series_id}/{series_id}.nii", f"{curr_dir}/Inference/{series_id}/{series_id}.nii.lz4"], check=True)

    archiving_time = time.time() - start_time

    log['total_segmentator_time'] = total_segmentator_time
    log['archiving_time'] = archiving_time

    shutil.rmtree(f"{curr_dir}/{converterType}/{series_id}", ignore_errors=True)

    global runtime_stats
    runtime_stats = pd.concat([runtime_stats, log], ignore_index=True, axis=0)

# %% [markdown]
# ###**Total Segmentator**

# %%
runtime_stats = pd.DataFrame(columns=['SeriesInstanceUID','total_segmentator_time',
                                      'archiving_time', 'cpu_usage','ram_usage_mb', 'ram_total_mb',
                                      'gpu_usage_mb', 'gpu_total_mb', 'gpu_type', 'disk_usage_all', 'disk_total'
                                      ])
if __name__ == "__main__":
    for series_id in os.listdir(f'{curr_dir}/{converterType}'):
        with ThreadPoolExecutor() as executor:
            monitor = MemoryMonitor()
            mem_thread = executor.submit(monitor.measure_usage)
            try:
                proc_thread = executor.submit(inferenceTotalSegmentator, series_id)
                proc_thread.result()
            finally:
                monitor.keep_measuring = False
                cpu_usage, ram_usage_mb, time_stamps, ram_total_mb, gpu_usage_mb, gpu_total_mb, gpu_type, disk_usage_all, disk_total= mem_thread.result()

                cpu_idx = runtime_stats.index[runtime_stats['SeriesInstanceUID'] == series_id][0]
                runtime_stats.iloc[cpu_idx, runtime_stats.columns.get_loc('cpu_usage')] = [[cpu_usage]]

                ram_usage_mb_idx = runtime_stats.index[runtime_stats['SeriesInstanceUID'] == series_id][0]
                runtime_stats.iloc[ram_usage_mb_idx, runtime_stats.columns.get_loc('ram_usage_mb')] = [[ram_usage_mb]]

                ram_total_mb_idx = runtime_stats.index[runtime_stats['SeriesInstanceUID'] == series_id][0]
                runtime_stats.iloc[ram_total_mb_idx, runtime_stats.columns.get_loc('ram_total_mb')] = [[ram_total_mb]]

                gpu_total_mb_idx = runtime_stats.index[runtime_stats['SeriesInstanceUID'] == series_id][0]
                runtime_stats.iloc[gpu_total_mb_idx, runtime_stats.columns.get_loc('gpu_total_mb')] = [[gpu_total_mb]]

                gpu_usage_mb_idx = runtime_stats.index[runtime_stats['SeriesInstanceUID'] == series_id][0]
                runtime_stats.iloc[gpu_usage_mb_idx, runtime_stats.columns.get_loc('gpu_usage_mb')] = [[gpu_usage_mb]]

                disk_usage_gb_idx = runtime_stats.index[runtime_stats['SeriesInstanceUID'] == series_id][0]
                runtime_stats.iloc[disk_usage_gb_idx, runtime_stats.columns.get_loc('disk_usage_all')] = [[disk_usage_all]]

                runtime_stats['gpu_type']=gpu_type
                runtime_stats['disk_total']=disk_total

                fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(8, 6))

                ax1.plot(time_stamps, cpu_usage)
                ax1.set_ylim(0, 100)
                ax1.set_xlabel('Time (s)')
                ax1.set_ylabel('CPU usage (%)')

                ax2.plot(time_stamps, ram_usage_mb)
                ax2.set_ylim(0, ram_total_mb)
                ax2.set_xlabel('Time (s)')
                ax2.set_ylabel('Memory usage (MB)')

                ax3.plot(time_stamps, gpu_usage_mb)
                ax3.set_ylim(0, gpu_total_mb)
                ax3.set_xlabel('Time (s)')
                ax3.set_ylabel('GPU Memory usage (MB)')

                ax4.plot(time_stamps, disk_usage_all)
                ax4.set_ylim(0, disk_total)
                ax4.set_xlabel('Time (s)')
                ax4.set_ylabel('Disk usage (GB)')
                plt.show()
# Out:
# Processing series: 1.3.6.1.4.1.14519.5.2.1.7009.9004.118722452529394350711166589345
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Downloading pretrained weights for Task 251 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 80.00s
# Downloading pretrained weights for Task 252 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 186.50s
# Downloading pretrained weights for Task 253 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 45.89s
# Downloading pretrained weights for Task 254 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 105.14s
# Downloading pretrained weights for Task 255 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 28.56s
# Resampling...
#   Resampled in 6.39s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Downloading pretrained weights for Task 251 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 80.00s
# Downloading pretrained weights for Task 252 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 186.50s
# Downloading pretrained weights for Task 253 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 45.89s
# Downloading pretrained weights for Task 254 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 105.14s
# Downloading pretrained weights for Task 255 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 28.56s
# Resampling...
#   Resampled in 6.39s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Downloading pretrained weights for Task 251 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 80.00s
# Downloading pretrained weights for Task 252 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 186.50s
# Downloading pretrained weights for Task 253 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 45.89s
# Downloading pretrained weights for Task 254 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 105.14s
# Downloading pretrained weights for Task 255 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 28.56s
# Resampling...
#   Resampled in 6.39s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Downloading pretrained weights for Task 251 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 80.00s
# Downloading pretrained weights for Task 252 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 186.50s
# Downloading pretrained weights for Task 253 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 45.89s
# Downloading pretrained weights for Task 254 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 105.14s
# Downloading pretrained weights for Task 255 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 28.56s
# Resampling...
#   Resampled in 6.39s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Downloading pretrained weights for Task 251 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 80.00s
# Downloading pretrained weights for Task 252 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 186.50s
# Downloading pretrained weights for Task 253 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 45.89s
# Downloading pretrained weights for Task 254 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 105.14s
# Downloading pretrained weights for Task 255 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 28.56s
# Resampling...
#   Resampled in 6.39s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Downloading pretrained weights for Task 251 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 80.00s
# Downloading pretrained weights for Task 252 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 186.50s
# Downloading pretrained weights for Task 253 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 45.89s
# Downloading pretrained weights for Task 254 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 105.14s
# Downloading pretrained weights for Task 255 (~230MB) ...
# Download finished. Extracting...
#   downloaded in 28.56s
# Resampling...
#   Resampled in 6.39s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 66.01s
# Resampling...
# Saving segmentations...
#   Saved in 0.74s
#
# Files moved successfully using the first command
# Processing series: 1.2.840.113654.2.55.113040386178547843571271236478024341696
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.23s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.23s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.23s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.23s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.23s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.23s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 66.68s
# Resampling...
# Saving segmentations...
#   Saved in 0.91s
#
# Files moved successfully using the first command
# Processing series: 1.3.6.1.4.1.14519.5.2.1.7009.9004.431377773401197924485551006033
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.93s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.93s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.93s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.93s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.93s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.93s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 52.41s
# Resampling...
# Saving segmentations...
#   Saved in 0.54s
#
# Files moved successfully using the first command
# Processing series: 1.2.840.113654.2.55.243990451406006403331425809632881193215
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.73s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.73s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.73s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.73s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.73s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.73s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 62.69s
# Resampling...
# Saving segmentations...
#   Saved in 0.51s
#
# Files moved successfully using the first command
# Processing series: 1.2.840.113654.2.55.100875189782210690344207306235124901243
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.52s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.52s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.52s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.52s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.52s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.52s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 61.67s
# Resampling...
# Saving segmentations...
#   Saved in 0.41s
#
# Files moved successfully using the first command
# Processing series: 1.2.840.113654.2.55.185309182591805634517860395342326800332
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 5.97s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 5.97s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 5.97s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 5.97s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 5.97s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 5.97s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 62.17s
# Resampling...
# Saving segmentations...
#   Saved in 0.54s
#
# Files moved successfully using the first command
# Processing series: 1.2.840.113654.2.55.14382674871619950799472325766084940706
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.31s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.31s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.31s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.31s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.31s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.31s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 57.57s
# Resampling...
# Saving segmentations...
#   Saved in 0.36s
#
# Files moved successfully using the first command
# Processing series: 1.2.840.113654.2.55.142419057730651121165090739113900499978
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.00s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.00s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.00s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.00s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.00s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.00s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 59.53s
# Resampling...
# Saving segmentations...
#   Saved in 0.69s
#
# Files moved successfully using the first command
# Processing series: 1.2.840.113654.2.55.146601594654322994982630019583270053397
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.34s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.34s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.34s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.34s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.34s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 6.34s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 62.62s
# Resampling...
# Saving segmentations...
#   Saved in 0.88s
#
# Files moved successfully using the first command
# Processing series: 1.2.840.113654.2.55.154809705591242159075253605419469935510
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 4.84s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 4.84s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 4.84s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 4.84s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 4.84s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 4.84s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 44.59s
# Resampling...
# Saving segmentations...
#   Saved in 0.32s
#
# Files moved successfully using the first command
# Processing series: 1.2.840.113654.2.55.216614002338888733987350522981366678482
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.51s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.51s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.51s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.51s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.51s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 7.51s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 57.96s
# Resampling...
# Saving segmentations...
#   Saved in 0.35s
#
# Files moved successfully using the first command
# Processing series: 1.2.840.113654.2.55.22770087029972268579113866309746562015
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.52s
# Predicting part 1 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.52s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.52s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.52s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.52s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#
# If you use this tool please cite: https://doi.org/10.48550/arXiv.2208.05868
#
# Resampling...
#   Resampled in 8.52s
# Predicting part 1 of 5 ...
# Predicting part 2 of 5 ...
# Predicting part 3 of 5 ...
# Predicting part 4 of 5 ...
# Predicting part 5 of 5 ...
#   Predicted in 61.04s
# Resampling...
# Saving segmentations...
#   Saved in 0.48s
#
# Files moved successfully using the first command

# %% [markdown]
# ###Compressing Output Files

# %%
start_time = time.time()
try:
  os.remove('inferenceNiftiFiles.tar.lz4')
  #os.remove('metadata.tar.lz4')
except OSError:
  pass
# !tar cvf - -C {curr_dir} Inference | lz4 > inferenceNiftiFiles.tar.lz4
#!tar cvf - -C {curr_dir} metadata | lz4 > inferenceMetaData.tar.lz4
archiving_time = time.time() - start_time
# Out:
# Inference/
# Inference/1.3.6.1.4.1.14519.5.2.1.7009.9004.118722452529394350711166589345/
# Inference/1.3.6.1.4.1.14519.5.2.1.7009.9004.118722452529394350711166589345/1.3.6.1.4.1.14519.5.2.1.7009.9004.118722452529394350711166589345.nii.lz4
# Inference/1.2.840.113654.2.55.113040386178547843571271236478024341696/
# Inference/1.2.840.113654.2.55.113040386178547843571271236478024341696/1.2.840.113654.2.55.113040386178547843571271236478024341696.nii.lz4
# Inference/1.3.6.1.4.1.14519.5.2.1.7009.9004.431377773401197924485551006033/
# Inference/1.3.6.1.4.1.14519.5.2.1.7009.9004.431377773401197924485551006033/1.3.6.1.4.1.14519.5.2.1.7009.9004.431377773401197924485551006033.nii.lz4
# Inference/1.2.840.113654.2.55.243990451406006403331425809632881193215/
# Inference/1.2.840.113654.2.55.243990451406006403331425809632881193215/1.2.840.113654.2.55.243990451406006403331425809632881193215.nii.lz4
# Inference/1.2.840.113654.2.55.100875189782210690344207306235124901243/
# Inference/1.2.840.113654.2.55.100875189782210690344207306235124901243/1.2.840.113654.2.55.100875189782210690344207306235124901243.nii.lz4
# Inference/1.2.840.113654.2.55.185309182591805634517860395342326800332/
# Inference/1.2.840.113654.2.55.185309182591805634517860395342326800332/1.2.840.113654.2.55.185309182591805634517860395342326800332.nii.lz4
# Inference/1.2.840.113654.2.55.14382674871619950799472325766084940706/
# Inference/1.2.840.113654.2.55.14382674871619950799472325766084940706/1.2.840.113654.2.55.14382674871619950799472325766084940706.nii.lz4
# Inference/1.2.840.113654.2.55.142419057730651121165090739113900499978/
# Inference/1.2.840.113654.2.55.142419057730651121165090739113900499978/1.2.840.113654.2.55.142419057730651121165090739113900499978.nii.lz4
# Inference/1.2.840.113654.2.55.146601594654322994982630019583270053397/
# Inference/1.2.840.113654.2.55.146601594654322994982630019583270053397/1.2.840.113654.2.55.146601594654322994982630019583270053397.nii.lz4
# Inference/1.2.840.113654.2.55.154809705591242159075253605419469935510/
# Inference/1.2.840.113654.2.55.154809705591242159075253605419469935510/1.2.840.113654.2.55.154809705591242159075253605419469935510.nii.lz4
# Inference/1.2.840.113654.2.55.216614002338888733987350522981366678482/
# Inference/1.2.840.113654.2.55.216614002338888733987350522981366678482/1.2.840.113654.2.55.216614002338888733987350522981366678482.nii.lz4
# Inference/1.2.840.113654.2.55.22770087029972268579113866309746562015/
# Inference/1.2.840.113654.2.55.22770087029972268579113866309746562015/1.2.840.113654.2.55.22770087029972268579113866309746562015.nii.lz4

# %% [markdown]
# ###**Utilization Metrics**

# %%
runtime_stats.to_csv('runtime.csv')
runtime_stats['archiving_time']=archiving_time
try:
  os.remove('inferenceUsageMetrics.lz4')
except OSError:
  pass
# !lz4 {curr_dir}/runtime.csv inferenceUsageMetrics.lz4
runtime_stats
# Out:
# Compressed 70218 bytes into 23242 bytes ==> 33.10%
#                                     SeriesInstanceUID  total_segmentator_time  \
# 0   1.3.6.1.4.1.14519.5.2.1.7009.9004.118722452529...              536.227986
# 1   1.2.840.113654.2.55.11304038617854784357127123...               85.864155
# 2   1.3.6.1.4.1.14519.5.2.1.7009.9004.431377773401...               68.463254
# 3   1.2.840.113654.2.55.24399045140600640333142580...               80.751376
# 4   1.2.840.113654.2.55.10087518978221069034420730...               77.787060
# 5   1.2.840.113654.2.55.18530918259180563451786039...               78.064631
# 6   1.2.840.113654.2.55.14382674871619950799472325...               72.883331
# 7   1.2.840.113654.2.55.14241905773065112116509073...               75.983778
# 8   1.2.840.113654.2.55.14660159465432299498263001...               80.069346
# 9   1.2.840.113654.2.55.15480970559124215907525360...               57.659188
# 10  1.2.840.113654.2.55.21661400233888873398735052...               73.536001
# 11  1.2.840.113654.2.55.22770087029972268579113866...               77.836804
#
#     archiving_time                                          cpu_usage  \
# 0          0.11114  [[[67.3, 99.5, 84.2, 97.5, 90.1, 94.0, 94.1, 5...
# 1          0.11114  [[[35.6, 53.4, 51.2, 56.5, 47.8, 86.7, 100.0, ...
# 2          0.11114  [[[51.3, 61.9, 46.8, 54.2, 52.2, 56.2, 87.1, 1...
# 3          0.11114  [[[58.0, 60.8, 52.5, 58.6, 53.7, 52.5, 52.0, 5...
# 4          0.11114  [[[53.0, 60.9, 68.1, 100.0, 100.0, 100.0, 100....
# 5          0.11114  [[[97.1, 100.0, 93.6, 58.5, 53.5, 53.7, 52.0, ...
# 6          0.11114  [[[26.2, 62.9, 53.5, 59.6, 53.0, 53.2, 78.3, 1...
# 7          0.11114  [[[26.4, 60.7, 52.5, 58.5, 54.2, 58.6, 100.0, ...
# 8          0.11114  [[[24.7, 92.1, 99.5, 100.0, 100.0, 89.5, 53.4,...
# 9          0.11114  [[[26.1, 61.9, 53.5, 59.7, 52.5, 52.5, 52.7, 6...
# 10         0.11114  [[[24.8, 62.9, 52.2, 58.4, 53.2, 52.2, 52.7, 1...
# 11         0.11114  [[[45.3, 60.4, 52.7, 58.2, 53.5, 52.0, 84.1, 1...
#
#                                          ram_usage_mb ram_total_mb  \
# 0   [[[1072.88671875, 1137.96484375, 1217.59765625...  [12982.625]
# 1   [[[1308.28515625, 1379.609375, 1487.71484375, ...  [12982.625]
# 2   [[[1314.953125, 1427.140625, 1498.40234375, 15...  [12982.625]
# 3   [[[1315.62109375, 1437.62109375, 1520.80078125...  [12982.625]
# 4   [[[1287.25, 1431.953125, 1513.03125, 1573.3359...  [12982.625]
# 5   [[[1284.51171875, 1392.7890625, 1480.890625, 1...  [12982.625]
# 6   [[[1329.671875, 1446.40234375, 1528.22265625, ...  [12982.625]
# 7   [[[1315.1015625, 1424.58984375, 1510.7109375, ...  [12982.625]
# 8   [[[1295.52734375, 1405.28515625, 1485.01953125...  [12982.625]
# 9   [[[1340.17578125, 1476.73828125, 1561.13671875...  [12982.625]
# 10  [[[1330.45703125, 1463.55859375, 1548.953125, ...  [12982.625]
# 11  [[[1325.55859375, 1473.828125, 1558.73046875, ...  [12982.625]
#
#                                          gpu_usage_mb gpu_total_mb  \
# 0   [[[258.3125, 258.3125, 258.3125, 258.3125, 258...    [15360.0]
# 1   [[[258.3125, 258.3125, 258.3125, 261.1875, 261...    [15360.0]
# 2   [[[258.3125, 258.3125, 258.3125, 261.1875, 261...    [15360.0]
# 3   [[[258.3125, 258.3125, 258.3125, 261.1875, 261...    [15360.0]
# 4   [[[258.3125, 258.3125, 258.3125, 261.1875, 261...    [15360.0]
# 5   [[[258.3125, 258.3125, 258.3125, 261.1875, 261...    [15360.0]
# 6   [[[258.3125, 258.3125, 258.3125, 261.1875, 261...    [15360.0]
# 7   [[[258.3125, 258.3125, 258.3125, 261.1875, 261...    [15360.0]
# 8   [[[258.3125, 258.3125, 258.3125, 258.3125, 261...    [15360.0]
# 9   [[[258.3125, 258.3125, 258.3125, 261.1875, 261...    [15360.0]
# 10  [[[258.3125, 258.3125, 258.3125, 261.1875, 261...    [15360.0]
# 11  [[[258.3125, 258.3125, 258.3125, 261.1875, 261...    [15360.0]
#
#        gpu_type                                     disk_usage_all  disk_total
# 0   b'Tesla T4'  [[[27.373027801513672, 27.373031616210938, 27....   78.189842
# 1   b'Tesla T4'  [[[28.495346069335938, 28.495349884033203, 28....   78.189842
# 2   b'Tesla T4'  [[[28.450359344482422, 28.450363159179688, 28....   78.189842
# 3   b'Tesla T4'  [[[28.424556732177734, 28.424560546875, 28.424...   78.189842
# 4   b'Tesla T4'  [[[28.3802490234375, 28.3802490234375, 28.3802...   78.189842
# 5   b'Tesla T4'  [[[28.34734344482422, 28.34734344482422, 28.34...   78.189842
# 6   b'Tesla T4'  [[[28.308059692382812, 28.308063507080078, 28....   78.189842
# 7   b'Tesla T4'  [[[28.277671813964844, 28.27767562866211, 28.2...   78.189842
# 8   b'Tesla T4'  [[[28.24340057373047, 28.243404388427734, 28.2...   78.189842
# 9   b'Tesla T4'  [[[28.2108154296875, 28.210819244384766, 28.21...   78.189842
# 10  b'Tesla T4'  [[[28.18332290649414, 28.183326721191406, 28.1...   78.189842
# 11  b'Tesla T4'  [[[28.14864730834961, 28.148651123046875, 28.1...   78.189842
