# %% [markdown]
# <a href="https://colab.research.google.com/github/vkt1414/Cloud-Resources-Workflows/blob/main/Notebooks/Totalsegmentator/radiomicsNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Installing Packages**

# %%
# %%capture
# !pip install gdown pyradiomics tqdm p_tqdm nibabel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyradiomics in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Requirement already satisfied: p_tqdm in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (3.0.2)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from pyradiomics) (1.22.4)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pyradiomics) (1.4.1)
# Requirement already satisfied: pykwalify>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pyradiomics) (1.8.0)
# Requirement already satisfied: SimpleITK>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from pyradiomics) (2.2.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from pyradiomics) (1.16.0)
# Requirement already satisfied: pathos>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from p_tqdm) (0.3.0)
# Requirement already satisfied: dill>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.5->p_tqdm) (0.3.6)
# Requirement already satisfied: multiprocess>=0.70.14 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.5->p_tqdm) (0.70.14)
# Requirement already satisfied: pox>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.5->p_tqdm) (0.3.2)
# Requirement already satisfied: ppft>=1.7.6.6 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.5->p_tqdm) (1.7.6.6)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from pykwalify>=1.6.0->pyradiomics) (2.8.2)
# Requirement already satisfied: ruamel.yaml>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from pykwalify>=1.6.0->pyradiomics) (0.17.22)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from pykwalify>=1.6.0->pyradiomics) (0.6.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml>=0.16.0->pykwalify>=1.6.0->pyradiomics) (0.2.7)

# %%
# %%capture
# !apt-get install lz4 wget

# %% [markdown]
# ###**Importing Packages**

# %%
import pathlib
from pathlib import Path
import json
from functools import partial
import time
import numpy as np
import pandas as pd
import nibabel as nib
from tqdm import tqdm
from p_tqdm import p_map
import numpy.ma as ma
import glob
import os
import SimpleITK as sitk
from radiomics import featureextractor

# %% [markdown]
# ###**Parameters for Papermill**

# %%
csvFilePath=''
inferenceNiftiFilePath=''
converterType='dcm2niix'

# %% [markdown]
# ###**Local testing**

# %%
# try:
#   os.remove(f'{curr_dir}/batch_1.csv')
#   os.remove(f'{curr_dir}/inferenceNiftiFiles.tar.lz4')
# except OSError:
#   pass

# !wget https://raw.githubusercontent.com/vkt1414/Cloud-Resources-Workflows/main/sampleManifests/batch_1.csv
# csvFilePath = glob.glob('*.csv')[0]

# !wget https://github.com/vkt1414/Cloud-Resources-Workflows/raw/main/sampleManifests/inferenceNiftiFiles.tar.lz4
# #Get the file path of the inferenceNiftiFiles
# inferenceNiftiFilePath=glob.glob('*.lz4')[0]

# %% [markdown]
# ###**Extracting Inference NIfTI files**

# %%
try:
  shutil.rmtree(f'Inference')
except OSError:
  pass
#!lz4 -d --rm {inferenceNiftiFilePath} -c | tar --strip-components=0 -xvf -

# !lz4 -d --rm {inferenceNiftiFilePath} -c | tar --strip-components=0 -xvf - 
#!rm -r Inference/1.2.840.113654.2.55.243990451406006403331425809632881193215/

# %% [markdown]
# ###**Reading CSV File containing s5cmd Urls**

# %%
start_time = time.time()
cohort_df=pd.read_csv(csvFilePath, delimiter=',', encoding='utf-8')
read_time=time.time() -start_time
print('read in '+str(read_time)+ '  seconds')

# %% [markdown]
# ###**Downloading Label maps from TotalSegmentator**

# %%
try:
  os.remove(f'{curr_dir}/map_to_binary.py')
except OSError:
  pass
# !wget https://raw.githubusercontent.com/wasserth/TotalSegmentator/master/totalsegmentator/map_to_binary.py
import map_to_binary
# Out:
# --2023-05-03 05:34:54--  https://raw.githubusercontent.com/wasserth/TotalSegmentator/master/totalsegmentator/map_to_binary.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16041 (16K) [text/plain]
# Saving to: ‘map_to_binary.py.1’
#
# map_to_binary.py.1  100%[===================>]  15.67K  --.-KB/s    in 0.001s
#
# 2023-05-03 05:34:54 (22.1 MB/s) - ‘map_to_binary.py.1’ saved [16041/16041]

# %% [markdown]
# ###**Functions**

# %%
def get_radiomics_features(seg_file, img_file, label=None):
    standard_features = ['shape_Elongation', 'shape_Flatness', 'shape_LeastAxisLength', 'shape_MajorAxisLength', 'shape_Maximum2DDiameterColumn', 'shape_Maximum2DDiameterRow', 'shape_Maximum2DDiameterSlice', 'shape_Maximum3DDiameter', 'shape_MeshVolume', 'shape_MinorAxisLength', 'shape_Sphericity', 'shape_SurfaceArea', 'shape_SurfaceVolumeRatio', 'shape_VoxelVolume', 'firstorder_10Percentile', 'firstorder_90Percentile', 'firstorder_Energy', 'firstorder_Entropy', 'firstorder_InterquartileRange', 'firstorder_Kurtosis', 'firstorder_Maximum', 'firstorder_MeanAbsoluteDeviation', 'firstorder_Mean', 'firstorder_Median', 'firstorder_Minimum', 'firstorder_Range', 'firstorder_RobustMeanAbsoluteDeviation', 'firstorder_RootMeanSquared', 'firstorder_Skewness', 'firstorder_TotalEnergy', 'firstorder_Uniformity', 'firstorder_Variance', 'glcm_Autocorrelation', 'glcm_ClusterProminence', 'glcm_ClusterShade', 'glcm_ClusterTendency', 'glcm_Contrast', 'glcm_Correlation', 'glcm_DifferenceAverage', 'glcm_DifferenceEntropy', 'glcm_DifferenceVariance', 'glcm_Id', 'glcm_Idm', 'glcm_Idmn', 'glcm_Idn', 'glcm_Imc1', 'glcm_Imc2', 'glcm_InverseVariance', 'glcm_JointAverage', 'glcm_JointEnergy', 'glcm_JointEntropy', 'glcm_MCC', 'glcm_MaximumProbability', 'glcm_SumAverage', 'glcm_SumEntropy', 'glcm_SumSquares', 'gldm_DependenceEntropy', 'gldm_DependenceNonUniformity', 'gldm_DependenceNonUniformityNormalized', 'gldm_DependenceVariance', 'gldm_GrayLevelNonUniformity', 'gldm_GrayLevelVariance', 'gldm_HighGrayLevelEmphasis', 'gldm_LargeDependenceEmphasis', 'gldm_LargeDependenceHighGrayLevelEmphasis', 'gldm_LargeDependenceLowGrayLevelEmphasis', 'gldm_LowGrayLevelEmphasis', 'gldm_SmallDependenceEmphasis', 'gldm_SmallDependenceHighGrayLevelEmphasis', 'gldm_SmallDependenceLowGrayLevelEmphasis', 'glrlm_GrayLevelNonUniformity', 'glrlm_GrayLevelNonUniformityNormalized', 'glrlm_GrayLevelVariance', 'glrlm_HighGrayLevelRunEmphasis', 'glrlm_LongRunEmphasis', 'glrlm_LongRunHighGrayLevelEmphasis', 'glrlm_LongRunLowGrayLevelEmphasis', 'glrlm_LowGrayLevelRunEmphasis', 'glrlm_RunEntropy', 'glrlm_RunLengthNonUniformity', 'glrlm_RunLengthNonUniformityNormalized', 'glrlm_RunPercentage', 'glrlm_RunVariance', 'glrlm_ShortRunEmphasis', 'glrlm_ShortRunHighGrayLevelEmphasis', 'glrlm_ShortRunLowGrayLevelEmphasis', 'glszm_GrayLevelNonUniformity', 'glszm_GrayLevelNonUniformityNormalized', 'glszm_GrayLevelVariance', 'glszm_HighGrayLevelZoneEmphasis', 'glszm_LargeAreaEmphasis', 'glszm_LargeAreaHighGrayLevelEmphasis', 'glszm_LargeAreaLowGrayLevelEmphasis', 'glszm_LowGrayLevelZoneEmphasis', 'glszm_SizeZoneNonUniformity', 'glszm_SizeZoneNonUniformityNormalized', 'glszm_SmallAreaEmphasis', 'glszm_SmallAreaHighGrayLevelEmphasis', 'glszm_SmallAreaLowGrayLevelEmphasis', 'glszm_ZoneEntropy', 'glszm_ZonePercentage', 'glszm_ZoneVariance', 'ngtdm_Busyness', 'ngtdm_Coarseness', 'ngtdm_Complexity', 'ngtdm_Contrast', 'ngtdm_Strength']
    settings = {}
    settings["resampledPixelSpacing"] = [3,3,3]
    settings["geometryTolerance"] = 1e-3
    settings["featureClass"] = ["shape"]
    extractor = featureextractor.RadiomicsFeatureExtractor(**settings)
    extractor.disableAllFeatures()
    extractor.enableFeatureClassByName("shape")
    extractor.enableFeatureClassByName("firstorder")
    features = extractor.execute(str(img_file), str(seg_file), label=label)
    features = {k.replace("original_", ""): v for k, v in features.items() if k.startswith("original_")}
    features = {k: round(float(v), 4) for k, v in features.items()}
    return label, features

# %%
def get_radiomics_features_for_all_labels(ct_file:Path, seg_file:Path, file_out:Path):
    label_id_body_part_data = map_to_binary.class_map['total'].items()
    # create a DataFrame from the extracted data
    label_id_body_part_df = pd.DataFrame(label_id_body_part_data, columns=['label_id', 'body_part'])
    stats = {}
    labels = [int(x) for x in np.unique(nib.load(seg_file).get_fdata()).tolist() if x != 0]
    for label in labels:
        mask_name, mask_stats = get_radiomics_features(seg_file, ct_file, label=label)
        # convert any ndarray objects to lists
        mask_stats = {k: v.tolist() if isinstance(v, np.ndarray) else v for k, v in mask_stats.items()}
        body_part = label_id_body_part_df.loc[label_id_body_part_df['label_id'] == label]['body_part'].values[0]
        stats[body_part] = mask_stats
    with open(file_out, "w") as f:
        json.dump(stats, f, indent=4)

# %%
ct_file = '/content/dcm2niix/1.2.840.113654.2.55.100875189782210690344207306235124901243/1.2.840.113654.2.55.100875189782210690344207306235124901243_0_OPA_GE_LSQX_STANDARD_360_2.5_120_na_na_na_19990102000000_2.nii.gz'
seg_file = '/content/segmentations.nii'
file_out = 'output.json'

get_radiomics_features_for_all_labels(ct_file, seg_file, file_out)
# Out:
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 1
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 1 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((324.5, 169.5, -0.5), (470.5, 311.5, 19.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [46, 46, 23]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 1
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [34 33 17]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [34 33 17]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 17 bins for bin width 25 with edges: [-150. -125. -100.  -75.  -50.  -25.    0.   25.   50.   75.  100.  125.
#   150.  175.  200.  225.  250.  275.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 2
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 2, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 2 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((161.5, 178.5, -0.5), (203.5, 225.5, 3.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [22, 23, 9]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 2
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [10 11  3]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [10 11  3]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 10 bins for bin width 25 with edges: [-75. -50. -25.   0.  25.  50.  75. 100. 125. 150. 175.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 3
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 3, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 3 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((328.5, 191.5, -0.5), (349.5, 221.5, 0.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3.  3.  2.5] and size [17, 19, 7]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 3
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [5 7 1]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [5 7 1]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 8 bins for bin width 25 with edges: [-50. -25.   0.  25.  50.  75. 100. 125. 150.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 5
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 5, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 5 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((36.5, 135.5, -0.5), (315.5, 427.5, 36.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [77, 81, 37]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 5
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [65 68 31]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [65 68 31]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 84 bins for bin width 25 with edges: [-600. -575. -550. -525. -500. -475. -450. -425. -400. -375. -350. -325.
#  -300. -275. -250. -225. -200. -175. -150. -125. -100.  -75.  -50.  -25.
#     0.   25.   50.   75.  100.  125.  150.  175.  200.  225.  250.  275.
#   300.  325.  350.  375.  400.  425.  450.  475.  500.  525.  550.  575.
#   600.  625.  650.  675.  700.  725.  750.  775.  800.  825.  850.  875.
#   900.  925.  950.  975. 1000. 1025. 1050. 1075. 1100. 1125. 1150. 1175.
#  1200. 1225. 1250. 1275. 1300. 1325. 1350. 1375. 1400. 1425. 1450. 1475.
#  1500.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 6
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 6, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 6 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((186.5, 234.5, 0.5), (384.5, 435.5, 36.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [59, 60, 37]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 6
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [46 47 30]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [46 47 30]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 88 bins for bin width 25 with edges: [-1100. -1075. -1050. -1025. -1000.  -975.  -950.  -925.  -900.  -875.
#   -850.  -825.  -800.  -775.  -750.  -725.  -700.  -675.  -650.  -625.
#   -600.  -575.  -550.  -525.  -500.  -475.  -450.  -425.  -400.  -375.
#   -350.  -325.  -300.  -275.  -250.  -225.  -200.  -175.  -150.  -125.
#   -100.   -75.   -50.   -25.     0.    25.    50.    75.   100.   125.
#    150.   175.   200.   225.   250.   275.   300.   325.   350.   375.
#    400.   425.   450.   475.   500.   525.   550.   575.   600.   625.
#    650.   675.   700.   725.   750.   775.   800.   825.   850.   875.
#    900.   925.   950.   975.  1000.  1025.  1050.  1075.  1100.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 7
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 7, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 7 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((199.5, 173.5, -0.5), (311.5, 341.5, 103.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [39, 52, 93]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 7
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [26 39 87]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [26 39 87]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 53 bins for bin width 25 with edges: [-475. -450. -425. -400. -375. -350. -325. -300. -275. -250. -225. -200.
#  -175. -150. -125. -100.  -75.  -50.  -25.    0.   25.   50.   75.  100.
#   125.  150.  175.  200.  225.  250.  275.  300.  325.  350.  375.  400.
#   425.  450.  475.  500.  525.  550.  575.  600.  625.  650.  675.  700.
#   725.  750.  775.  800.  825.  850.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 8
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 8, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 8 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((186.5, 251.5, -0.5), (246.5, 311.5, 42.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [26, 27, 42]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 8
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [14 14 36]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [14 14 36]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 16 bins for bin width 25 with edges: [-150. -125. -100.  -75.  -50.  -25.    0.   25.   50.   75.  100.  125.
#   150.  175.  200.  225.  250.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 9
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 9, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 9 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((152.5, 259.5, -0.5), (375.5, 337.5, 11.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [65, 31, 16]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 9
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [52 18 10]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [52 18 10]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 19 bins for bin width 25 with edges: [-100.  -75.  -50.  -25.    0.   25.   50.   75.  100.  125.  150.  175.
#   200.  225.  250.  275.  300.  325.  350.  375.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 10
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 10, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 10 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((229.5, 281.5, -0.5), (337.5, 332.5, 7.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [38, 24, 13]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 10
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [25 12  7]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [25 12  7]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 11 bins for bin width 25 with edges: [-100.  -75.  -50.  -25.    0.   25.   50.   75.  100.  125.  150.  175.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 11
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 11, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# ...
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [ 34  25 112]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 23 bins for bin width 25 with edges: [-175. -150. -125. -100.  -75.  -50.  -25.    0.   25.   50.   75.  100.
#   125.  150.  175.  200.  225.  250.  275.  300.  325.  350.  375.  400.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 101
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 101, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 101 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((143.5, 88.5, -0.5), (259.5, 195.5, 134.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [39, 37, 113]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 101
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [ 27  24 112]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [ 27  24 112]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 27 bins for bin width 25 with edges: [-200. -175. -150. -125. -100.  -75.  -50.  -25.    0.   25.   50.   75.
#   100.  125.  150.  175.  200.  225.  250.  275.  300.  325.  350.  375.
#   400.  425.  450.  475.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 102
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 102, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 102 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((298.5, 156.5, -0.5), (311.5, 178.5, 4.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [16, 17, 10]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 102
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [3 5 4]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [3 5 4]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 6 bins for bin width 25 with edges: [  0.  25.  50.  75. 100. 125. 150.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted
# INFO:radiomics.featureextractor:No valid config parameter, using defaults: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True}
# INFO:radiomics.featureextractor:Enabled image types: {'Original': {}}
# INFO:radiomics.featureextractor:Enabled features: {'firstorder': [], 'glcm': [], 'gldm': [], 'glrlm': [], 'glszm': [], 'ngtdm': [], 'shape': []}
# INFO:radiomics.featureextractor:Applying custom setting overrides: {'resampledPixelSpacing': [3, 3, 3], 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# DEBUG:radiomics.featureextractor:Setting SimpleITK tolerance to 0.001
# DEBUG:radiomics.featureextractor:Disabling all feature classes
# DEBUG:radiomics.featureextractor:Enabling all features in class shape
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': []}
# DEBUG:radiomics.featureextractor:Enabling all features in class firstorder
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# INFO:radiomics.featureextractor:Calculating features with label: 103
# DEBUG:radiomics.featureextractor:Enabled images types: {'Original': {}}
# DEBUG:radiomics.featureextractor:Enabled features: {'shape': [], 'firstorder': []}
# DEBUG:radiomics.featureextractor:Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 103, 'additionalInfo': True, 'geometryTolerance': 0.001, 'featureClass': ['shape']}
# INFO:radiomics.featureextractor:Loading image and mask
# DEBUG:radiomics.imageoperations:Force casting mask to UInt32 to ensure correct datatype.
# DEBUG:radiomics.imageoperations:Resampling image and mask
# DEBUG:radiomics.imageoperations:Where resampled spacing is set to 0, set it to the original spacing (mask)
# DEBUG:radiomics.imageoperations:Checking ROI validity
# DEBUG:radiomics.imageoperations:Checking if label 103 is persent in the mask
# DEBUG:radiomics.imageoperations:Comparing physical space of bounding box to physical space of image
# DEBUG:radiomics.imageoperations:ROI bounds (image coordinate space): ((208.5, 148.5, -0.5), (221.5, 165.5, 5.5))
# DEBUG:radiomics.imageoperations:ROI valid, calculating resampling grid
# DEBUG:radiomics.imageoperations:Comparing resampled spacing to original spacing (image
# INFO:radiomics.imageoperations:Applying resampling from spacing [0.703125 0.703125 2.5     ] and size [512 512 135] to spacing [3. 3. 3.] and size [15, 16, 11]
# DEBUG:radiomics.imageoperations:Resampling image
# DEBUG:radiomics.imageoperations:Resampling mask
# DEBUG:radiomics.imageoperations:Checking mask with label 103
# DEBUG:radiomics.imageoperations:Calculating bounding box
# DEBUG:radiomics.imageoperations:Checking minimum number of dimensions requirements (2)
# DEBUG:radiomics.featureextractor:Image and Mask loaded and valid, starting extraction
# DEBUG:radiomics.imageoperations:Cropping to size [3 4 5]
# INFO:radiomics.featureextractor:Computing shape
# DEBUG:radiomics.shape:Initializing feature class
# DEBUG:radiomics.shape:Padding the mask with 0s
# DEBUG:radiomics.shape:Pre-calculate Volume, Surface Area and Eigenvalues
# DEBUG:radiomics.shape:Shape feature class initialized
# DEBUG:radiomics.shape:Calculating features
# DEBUG:radiomics.featureextractor:Creating image type iterator
# INFO:radiomics.featureextractor:Adding image type "Original" with custom settings: {}
# DEBUG:radiomics.featureextractor:Extracting features
# DEBUG:radiomics.imageoperations:Yielding original image
# INFO:radiomics.featureextractor:Calculating features for original image
# DEBUG:radiomics.imageoperations:Cropping to size [3 4 5]
# INFO:radiomics.featureextractor:Computing firstorder
# DEBUG:radiomics.firstorder:Initializing feature class
# DEBUG:radiomics.imageoperations:Discretizing gray levels inside ROI
# DEBUG:radiomics.imageoperations:Calculated 9 bins for bin width 25 with edges: [-50. -25.   0.  25.  50.  75. 100. 125. 150. 175.])
# DEBUG:radiomics.firstorder:First order feature class initialized
# DEBUG:radiomics.firstorder:Calculating features
# DEBUG:radiomics.featureextractor:Features extracted

# %%
def get_radiomics_features(seg_file, img_file="ct.nii.gz"):
    # import SimpleITK as sitk
    import radiomics
    from radiomics import featureextractor

    standard_features = ['shape_Elongation', 'shape_Flatness', 'shape_LeastAxisLength', 'shape_MajorAxisLength', 'shape_Maximum2DDiameterColumn', 'shape_Maximum2DDiameterRow', 'shape_Maximum2DDiameterSlice', 'shape_Maximum3DDiameter', 'shape_MeshVolume', 'shape_MinorAxisLength', 'shape_Sphericity', 'shape_SurfaceArea', 'shape_SurfaceVolumeRatio', 'shape_VoxelVolume', 'firstorder_10Percentile', 'firstorder_90Percentile', 'firstorder_Energy', 'firstorder_Entropy', 'firstorder_InterquartileRange', 'firstorder_Kurtosis', 'firstorder_Maximum', 'firstorder_MeanAbsoluteDeviation', 'firstorder_Mean', 'firstorder_Median', 'firstorder_Minimum', 'firstorder_Range', 'firstorder_RobustMeanAbsoluteDeviation', 'firstorder_RootMeanSquared', 'firstorder_Skewness', 'firstorder_TotalEnergy', 'firstorder_Uniformity', 'firstorder_Variance', 'glcm_Autocorrelation', 'glcm_ClusterProminence', 'glcm_ClusterShade', 'glcm_ClusterTendency', 'glcm_Contrast', 'glcm_Correlation', 'glcm_DifferenceAverage', 'glcm_DifferenceEntropy', 'glcm_DifferenceVariance', 'glcm_Id', 'glcm_Idm', 'glcm_Idmn', 'glcm_Idn', 'glcm_Imc1', 'glcm_Imc2', 'glcm_InverseVariance', 'glcm_JointAverage', 'glcm_JointEnergy', 'glcm_JointEntropy', 'glcm_MCC', 'glcm_MaximumProbability', 'glcm_SumAverage', 'glcm_SumEntropy', 'glcm_SumSquares', 'gldm_DependenceEntropy', 'gldm_DependenceNonUniformity', 'gldm_DependenceNonUniformityNormalized', 'gldm_DependenceVariance', 'gldm_GrayLevelNonUniformity', 'gldm_GrayLevelVariance', 'gldm_HighGrayLevelEmphasis', 'gldm_LargeDependenceEmphasis', 'gldm_LargeDependenceHighGrayLevelEmphasis', 'gldm_LargeDependenceLowGrayLevelEmphasis', 'gldm_LowGrayLevelEmphasis', 'gldm_SmallDependenceEmphasis', 'gldm_SmallDependenceHighGrayLevelEmphasis', 'gldm_SmallDependenceLowGrayLevelEmphasis', 'glrlm_GrayLevelNonUniformity', 'glrlm_GrayLevelNonUniformityNormalized', 'glrlm_GrayLevelVariance', 'glrlm_HighGrayLevelRunEmphasis', 'glrlm_LongRunEmphasis', 'glrlm_LongRunHighGrayLevelEmphasis', 'glrlm_LongRunLowGrayLevelEmphasis', 'glrlm_LowGrayLevelRunEmphasis', 'glrlm_RunEntropy', 'glrlm_RunLengthNonUniformity', 'glrlm_RunLengthNonUniformityNormalized', 'glrlm_RunPercentage', 'glrlm_RunVariance', 'glrlm_ShortRunEmphasis', 'glrlm_ShortRunHighGrayLevelEmphasis', 'glrlm_ShortRunLowGrayLevelEmphasis', 'glszm_GrayLevelNonUniformity', 'glszm_GrayLevelNonUniformityNormalized', 'glszm_GrayLevelVariance', 'glszm_HighGrayLevelZoneEmphasis', 'glszm_LargeAreaEmphasis', 'glszm_LargeAreaHighGrayLevelEmphasis', 'glszm_LargeAreaLowGrayLevelEmphasis', 'glszm_LowGrayLevelZoneEmphasis', 'glszm_SizeZoneNonUniformity', 'glszm_SizeZoneNonUniformityNormalized', 'glszm_SmallAreaEmphasis', 'glszm_SmallAreaHighGrayLevelEmphasis', 'glszm_SmallAreaLowGrayLevelEmphasis', 'glszm_ZoneEntropy', 'glszm_ZonePercentage', 'glszm_ZoneVariance', 'ngtdm_Busyness', 'ngtdm_Coarseness', 'ngtdm_Complexity', 'ngtdm_Contrast', 'ngtdm_Strength']
    
    try:
        if len(np.unique(nib.load(seg_file).get_fdata())) > 1:
            settings = {}
            # settings["binWidth"] = 25
            # settings["resampledPixelSpacing"] = None  # [3,3,3] is an example for defining resampling (voxels with size 3x3x3mm)
            settings["resampledPixelSpacing"] = [3,3,3]
            # settings["interpolator"] = sitk.sitkBSpline
            settings["geometryTolerance"] = 1e-3  # default: 1e-6
            settings["featureClass"] = ["shape"]
            extractor = featureextractor.RadiomicsFeatureExtractor(**settings)
            # Only use subset of features
            extractor.disableAllFeatures()
            extractor.enableFeatureClassByName("shape")
            extractor.enableFeatureClassByName("firstorder")
            features = extractor.execute(str(img_file), str(seg_file))
            
            features = {k.replace("original_", ""): v for k, v in features.items() if k.startswith("original_")}
        else:
            print("WARNING: Entire mask is 0 or 1. Setting all features to 0")
            features = {feat: 0 for feat in standard_features}
    except Exception as e:
        print(f"WARNING: radiomics raised an exception (settings all features to 0): {e}")
        features = {feat: 0 for feat in standard_features}

    # only keep subset of features
    # meaningful_features = ['shape_Elongation', 'shape_Flatness', 'shape_LeastAxisLength']
    # features = {k: v for k, v in features.items() if k in meaningful_features}  

    features = {k: round(float(v), 4) for k, v in features.items()}  # round to 4 decimals and cast to python float
    
    return seg_file.name.split(".")[0], features

# %%
def get_radiomics_features_for_entire_dir(ct_file:Path, mask_dir:Path, file_out:Path):
    masks = sorted(list(mask_dir.glob("*.nii.gz")))
    stats = p_map(partial(get_radiomics_features, img_file=ct_file),
                    masks, num_cpus=1, disable=False)
    stats = {mask_name: stats for mask_name, stats in stats}
    with open(file_out, "w") as f:
        json.dump(stats, f, indent=4)
