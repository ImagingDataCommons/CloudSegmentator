# %% [markdown]
# <a href="https://colab.research.google.com/github/vkt1414/Cloud-Resources-Workflows/blob/main/Notebooks/Totalsegmentator/executionAnalytics/sevenBridgesCostAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install sevenbridges-python

# %%
import sevenbridges as sbg

# %%
token=''

# %%
api = sbg.Api(url='https://cgc-api.sbgenomics.com/v2', token=token,advance_access=True)
# Out:
# WARNING:sevenbridges.http.client:Advance access features enabled. AA API calls can be subject to changes.

# %%
projectIds = []
for project in api.projects.query().all():
    projectIds.append(project.id)
projectIds
# Out:
# ['vamsikrishna14/idc-gcp', 'vamsikrishna14/idc']

# %%
import pandas as pd

data = []
for project in projectIds:
  for task in api.tasks.query(project=project, order_by='end_time',status='COMPLETED').all():
      data.append([task.id, project, task.batch])

df = pd.DataFrame(data, columns=['id','projectId', 'batch'])
df
# Out:
#                                       id               projectId  batch
# 0   51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# 1   d9b989a0-528a-4f75-b973-d990ef3126a3      vamsikrishna14/idc   True
# 2   070efffe-ffb2-49d9-a55b-8f91eabe5c47      vamsikrishna14/idc   True
# 3   2314f3fc-69af-49e6-84cb-7d1a31e6ef69      vamsikrishna14/idc  False
# 4   52282048-5197-4578-aaa7-31e9e2cfd8bb      vamsikrishna14/idc  False
# ..                                   ...                     ...    ...
# 66  dab9dad1-918a-406e-84c4-d7f7c1476a37      vamsikrishna14/idc   True
# 67  2f6bd4f0-49c0-4dc2-b905-c1e3edf05a90      vamsikrishna14/idc  False
# 68  0dcc6b33-5c51-43f3-b90d-0052229052fe      vamsikrishna14/idc  False
# 69  14b442d2-5d99-4162-bb49-833eed086a89      vamsikrishna14/idc  False
# 70  fdc9ade3-0c66-4f0e-ad77-e914d543c9d2      vamsikrishna14/idc  False
#
# [71 rows x 3 columns]

# %%
batch_tasks = df[df['batch'] == True].copy()
individual_tasks = df[df['batch'] == False].copy()
individual_tasks.loc[:, 'batchId'] = ''
individual_tasks.rename(columns={'id': 'taskId'}, inplace=True)
batch_tasks.rename(columns={'id': 'batchId'}, inplace=True)
individual_tasks
# Out:
#                                   taskId           projectId  batch batchId
# 3   2314f3fc-69af-49e6-84cb-7d1a31e6ef69  vamsikrishna14/idc  False
# 4   52282048-5197-4578-aaa7-31e9e2cfd8bb  vamsikrishna14/idc  False
# 5   33ce72bc-1a83-4cac-9aa2-84a63e98f9b9  vamsikrishna14/idc  False
# 6   5c24bbba-8402-40a0-a304-2c865d7eaa3a  vamsikrishna14/idc  False
# 7   39bc9c3b-02c3-4bb1-bd98-7aa8f324d8cc  vamsikrishna14/idc  False
# 8   292e3d5f-a6d9-4c4a-aa4e-68d212414441  vamsikrishna14/idc  False
# 9   abcc5908-0a70-4705-b9cf-744e83c32eb0  vamsikrishna14/idc  False
# 10  893fa84c-1741-46f7-94c8-aba4a64c63bb  vamsikrishna14/idc  False
# 11  7a001fc0-d98d-4fd7-9b47-e652eea6c5f0  vamsikrishna14/idc  False
# 12  6097b2a2-db4c-4aa6-a240-ab87105bd4be  vamsikrishna14/idc  False
# 13  ba033928-9182-48d4-acb8-cc1a49244cb5  vamsikrishna14/idc  False
# 14  5a3849cc-add1-417b-8065-3662e206cbfc  vamsikrishna14/idc  False
# 15  c7c5e6ee-d516-4110-ae6b-37bee26ee6c2  vamsikrishna14/idc  False
# 16  8b13a667-f215-4d76-a823-caaf518422e1  vamsikrishna14/idc  False
# 17  cf87a036-e446-4e01-b508-b495fd317fc9  vamsikrishna14/idc  False
# 18  bc1deb79-e386-4bf5-8686-9bbddeefa415  vamsikrishna14/idc  False
# 23  4cd03d66-a35f-4dd9-a02a-d689ac7ce391  vamsikrishna14/idc  False
# 25  fac14bdd-21a4-4e52-b17e-464252db4ffc  vamsikrishna14/idc  False
# 36  f3b88ead-89a1-4e22-b100-e2302b3b2fb4  vamsikrishna14/idc  False
# 38  2b0d4743-8495-4ba7-b30b-3e6f3c2ee19b  vamsikrishna14/idc  False
# 40  ce582481-e2af-4785-b7fe-3a0c2a2c9820  vamsikrishna14/idc  False
# 41  53708c46-c429-4336-bcb1-36d5330b8318  vamsikrishna14/idc  False
# 42  19ea24bb-5c2c-410a-8798-0ef0f93909cd  vamsikrishna14/idc  False
# 43  a172d30a-2005-4221-8882-99871961b264  vamsikrishna14/idc  False
# 44  e454ed99-85f3-47ca-92fd-c2ef1fe655da  vamsikrishna14/idc  False
# 45  57d7466c-09df-4ad3-a25b-3760c9ea5e08  vamsikrishna14/idc  False
# 46  9a797c04-d7eb-4ecc-8e01-7f446e087fdb  vamsikrishna14/idc  False
# 47  d944ee0b-393f-4d98-b82a-4fd1134824f2  vamsikrishna14/idc  False
# 48  8dad027c-cfb8-47d3-b836-7029cffa834e  vamsikrishna14/idc  False
# 49  5a54788a-5632-4ffd-a404-ddabe0723ede  vamsikrishna14/idc  False
# 50  4b30fb4d-fa5f-4b7e-9eed-3ec6ae1c862e  vamsikrishna14/idc  False
# 51  a5853f37-b7e9-481d-9084-a5cbda761283  vamsikrishna14/idc  False
# 52  13393d83-4184-4ed3-bc66-a5b38e753518  vamsikrishna14/idc  False
# 53  2dfda7dd-d9f2-473f-a8d0-8bda06b70537  vamsikrishna14/idc  False
# 54  bed99307-62ce-4723-a167-3cf0aac44a66  vamsikrishna14/idc  False
# 55  53acdc54-a950-4e19-aceb-dbd835aca0ff  vamsikrishna14/idc  False
# 56  e1f9818a-254f-4bff-9f66-803059bbd735  vamsikrishna14/idc  False
# 57  97179f9d-19a5-456b-b56f-b1deaf16e2ab  vamsikrishna14/idc  False
# 58  9a342ff0-a852-4f23-920b-16a48b591620  vamsikrishna14/idc  False
# 59  b53fddb2-4999-400f-99b3-e123a7e66480  vamsikrishna14/idc  False
# 60  1347a554-7dba-4304-a236-88a078cc3721  vamsikrishna14/idc  False
# 61  b3191dc7-d724-4129-8f6d-7eabbf941c85  vamsikrishna14/idc  False
# 62  ecb84015-c24a-4f25-88a2-6d12456ed094  vamsikrishna14/idc  False
# 63  81e3be56-20e7-47a8-ac14-0e1e9173b5de  vamsikrishna14/idc  False
# 64  fd69db5b-ac24-4c9d-8788-bcf64e3dd85f  vamsikrishna14/idc  False
# 65  ab31f9d3-41f3-4ed6-9df3-745037ceee7a  vamsikrishna14/idc  False
# 67  2f6bd4f0-49c0-4dc2-b905-c1e3edf05a90  vamsikrishna14/idc  False
# 68  0dcc6b33-5c51-43f3-b90d-0052229052fe  vamsikrishna14/idc  False
# 69  14b442d2-5d99-4162-bb49-833eed086a89  vamsikrishna14/idc  False
# 70  fdc9ade3-0c66-4f0e-ad77-e914d543c9d2  vamsikrishna14/idc  False

# %%
batch_tasks_ids = batch_tasks['batchId'].tolist()
batch_data = []

for batchId in batch_tasks_ids:
    for task in api.tasks.query(order_by='end_time', parent=batchId, status='COMPLETED').all():
        batch_data.append([task.id, batchId ])

batch = pd.DataFrame(batch_data, columns=['taskId', 'batchId'])
batch_df = pd.merge(batch_tasks, batch, on='batchId', how='left').drop_duplicates().reset_index(drop=True)
batch_df
# Out:
#                                   batchId               projectId  batch  \
# 0    51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# 1    51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# 2    51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# 3    51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# 4    51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# ..                                    ...                     ...    ...
# 327  de77e463-9f2f-4fbc-819e-913886e871c6      vamsikrishna14/idc   True
# 328  de77e463-9f2f-4fbc-819e-913886e871c6      vamsikrishna14/idc   True
# 329  de77e463-9f2f-4fbc-819e-913886e871c6      vamsikrishna14/idc   True
# 330  dab9dad1-918a-406e-84c4-d7f7c1476a37      vamsikrishna14/idc   True
# 331  dab9dad1-918a-406e-84c4-d7f7c1476a37      vamsikrishna14/idc   True
#
#                                    taskId
# 0    88426f22-bc3f-432d-926b-985c8b7fd972
# 1    1b76b86a-6584-4a91-af69-e29886db42e9
# 2    099b4671-e8ba-4e25-989e-406567829123
# 3    3b63a523-2602-41c8-b9de-04df909d70af
# 4    a0d43719-5f09-4f5f-a5c9-4ee08e6f6559
# ..                                    ...
# 327  e34b19bf-5e06-44c7-a6ba-266b164caafc
# 328  f80924b7-ff0d-4d30-be7c-a067dc32c24b
# 329  1ebe0f22-204e-4bf8-b0a0-267f14219d27
# 330  e73a02d8-982f-4baf-8f06-e62809213d27
# 331  604f408e-436b-446e-9001-36e99a8385f1
#
# [332 rows x 4 columns]

# %%
final_task_df= pd.concat([batch_df,individual_tasks ])
final_task_df
# Out:
#                                  batchId               projectId  batch  \
# 0   51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# 1   51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# 2   51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# 3   51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# 4   51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp   True
# ..                                   ...                     ...    ...
# 65                                            vamsikrishna14/idc  False
# 67                                            vamsikrishna14/idc  False
# 68                                            vamsikrishna14/idc  False
# 69                                            vamsikrishna14/idc  False
# 70                                            vamsikrishna14/idc  False
#
#                                   taskId
# 0   88426f22-bc3f-432d-926b-985c8b7fd972
# 1   1b76b86a-6584-4a91-af69-e29886db42e9
# 2   099b4671-e8ba-4e25-989e-406567829123
# 3   3b63a523-2602-41c8-b9de-04df909d70af
# 4   a0d43719-5f09-4f5f-a5c9-4ee08e6f6559
# ..                                   ...
# 65  ab31f9d3-41f3-4ed6-9df3-745037ceee7a
# 67  2f6bd4f0-49c0-4dc2-b905-c1e3edf05a90
# 68  0dcc6b33-5c51-43f3-b90d-0052229052fe
# 69  14b442d2-5d99-4162-bb49-833eed086a89
# 70  fdc9ade3-0c66-4f0e-ad77-e914d543c9d2
#
# [382 rows x 4 columns]

# %%
# task_ids = final_task_df['taskId'].tolist()

# data = []
# for task_id in task_ids:
#     task_details = api.tasks.get(id=task_id)
#     outputs = task_details.outputs
#     if isinstance(outputs, dict):
#         for key, value in outputs.items():
#             if value is not None and hasattr(value, 'id'):
#                 new_row = [
#                     task_details.id,
#                     task_details.name,
#                     task_details.status,
#                     task_details.project,
#                     task_details.app,
#                     task_details.type,
#                     task_details.batch,
#                     task_details.created_by,
#                     task_details.executed_by,
#                     task_details.start_time,
#                     task_details.end_time,
#                     task_details.price.amount,
#                     task_details.price.breakdown.storage,
#                     task_details.price.breakdown.computation,
#                     task_details.execution_status.steps_completed,
#                     task_details.execution_status.system_limit,
#                     task_details.execution_status.account_limit,
#                     task_details.execution_status.instance_init,
#                     task_details.execution_status.steps_total,
#                     task_details.execution_status.message,
#                     task_details.execution_status.duration,
#                     task_details.execution_status.queued_duration,
#                     task_details.execution_status.running_duration,
#                     task_details.execution_status.execution_duration,
#                     key,
#                     value.id
#                 ]
#                 data.append(new_row)

# details_df = pd.DataFrame(
#     data,
#     columns=[
#         'taskId',
#         'name',
#         'status',
#         'project',
#         'app',
#         'type',
#         'batch',
#         'created_by',
#         'executed_by',
#         'start_time',
#         'end_time',
#         'price',
#         'storage_price',
#         'compute_price',
#         'steps_completed',
#         'system_limit',
#         'account_limit',
#         'instance_init',
#         'steps_total',
#         'message',
#         'duration',
#         'queued_duration',
#         'running_duration',
#         'execution_duration',
#         'output_key',
#         'output_file_id'
#     ]
# )
# details_df

# %%
# # Get the task IDs from the final task dataframe
# import time
# task_ids = final_task_df['taskId'].tolist()

# # Create an empty list to store the data
# data = []

# # Initialize a counter for the number of API requests made
# api_request_count = 0

# # Iterate over the task IDs
# for task_id in task_ids:

#     # Get the task details
#     task_details = api.tasks.get(id=task_id)

#     # Get the outputs
#     outputs = task_details.outputs

#     # Get the execution details
#     executionDetails= task_details.get_execution_details() 

#     # If the outputs are a dictionary
#     if isinstance(outputs, dict):

#         # Iterate over the keys and values in the outputs dictionary
#         for key, value in outputs.items():

#             # If the value is not None and has an ID
#             if value is not None and hasattr(value, 'id'):

#                 # Iterate over the jobs
#                 for job in executionDetails.jobs:
                
#                     # Create a new row for each job
#                     new_row = [
#                         task_details.id,
#                         task_details.name,
#                         task_details.status,
#                         task_details.project,
#                         task_details.app,
#                         task_details.type,
#                         task_details.batch,
#                         task_details.created_by,
#                         task_details.executed_by,
#                         task_details.start_time,
#                         task_details.end_time,
#                         task_details.price.amount,
#                         task_details.price.breakdown.storage,
#                         task_details.price.breakdown.computation,
#                         task_details.execution_status.steps_completed,
#                         task_details.execution_status.system_limit,
#                         task_details.execution_status.account_limit,
#                         task_details.execution_status.instance_init,
#                         task_details.execution_status.steps_total,
#                         task_details.execution_status.message,
#                         task_details.execution_status.duration,
#                         task_details.execution_status.queued_duration,
#                         task_details.execution_status.running_duration,
#                         task_details.execution_status.execution_duration,
#                         key,
#                         value.id,
#                         job.name,
#                         job.start_time,
#                         job.end_time,
#                         job.status,
#                         job.instance.id,
#                         job.instance.type,
#                         job.instance.provider,
#                         job.instance.disk.size,
#                         job.instance.disk.unit,
#                         job.instance.disk.type
#                     ]

#                     # Append the new row to the data list
#                     data.append(new_row)

#                     # Increment the API request counter
#                     api_request_count += 1

#                     # If we have made 500 API requests, wait for 5.5 minutes
#                     if api_request_count == 500:
#                         time.sleep(330)  # 330 seconds = 5.5 minutes
#                         api_request_count = 0  # reset the API request counter


# # Create a DataFrame from the data list
# details_df = pd.DataFrame(
#     data,
#     columns=[
#         'taskId',
#         'name',
#         'status',
#         'project',
#         'app',
#         'type',
#         'batch',
#         'created_by',
#         'executed_by',
#         'start_time',
#         'end_time',
#         'price',
#         'storage_price',
#         'compute_price',
#         'steps_completed',
#         'system_limit',
#         'account_limit',
#         'instance_init',
#         'steps_total',
#         'message',
#         'duration',
#         'queued_duration',
#         'running_duration',
#         'execution_duration',
#         'output_key',
#         'output_file_id',
#         'job_name',
#         'job_start_time',
#         'job_end_time',
#         'job_status',
#         'instance_id',
#         'instance_type',
#         'instance_provider',
#         'instance_disk_size',
#         'instance_disk_unit',
#         'instance_disk_type'
#     ]
# )
# details_df

# %%
# Get the task IDs from the final task dataframe
import time
task_ids = final_task_df['taskId'].tolist()

# Create an empty list to store the data
data = []

# Initialize the API request count and time
api_request_count = 0
api_request_time = time.time()

# Iterate over the task IDs
for task_id in task_ids:

    # Get the task details
    task_details = api.tasks.get(id=task_id)
    api_request_count += 1

    # Get the outputs
    outputs = task_details.outputs
    api_request_count += 1

    # Get the execution details
    executionDetails= task_details.get_execution_details() 
    api_request_count += 1

    # Check if the API request count is a multiple of 500
    if api_request_count % 500 == 0:

        # Calculate the time elapsed since the last API request
        elapsed_time = time.time() - api_request_time

        # If less than 5.5 minutes have elapsed, sleep for the remaining time
        if elapsed_time < 330:
            time.sleep(330 - elapsed_time)

        # Reset the API request time
        api_request_time = time.time()

    # If the outputs are a dictionary
    if isinstance(outputs, dict):

        # Iterate over the keys and values in the outputs dictionary
        for key, value in outputs.items():

            # If the value is not None and has an ID
            if value is not None and hasattr(value, 'id'):

                # Iterate over the jobs
                for job in executionDetails.jobs:
                
                    # Create a new row for each job
                    new_row = [
                        task_details.id,
                        task_details.name,
                        task_details.status,
                        task_details.project,
                        task_details.app,
                        task_details.type,
                        task_details.batch,
                        task_details.created_by,
                        task_details.executed_by,
                        task_details.start_time,
                        task_details.end_time,
                        task_details.price.amount,
                        task_details.price.breakdown.storage,
                        task_details.price.breakdown.computation,
                        task_details.execution_status.steps_completed,
                        task_details.execution_status.system_limit,
                        task_details.execution_status.account_limit,
                        task_details.execution_status.instance_init,
                        task_details.execution_status.steps_total,
                        task_details.execution_status.message,
                        task_details.execution_status.duration,
                        task_details.execution_status.queued_duration,
                        task_details.execution_status.running_duration,
                        task_details.execution_status.execution_duration,
                        key,
                        value.id,
                        job.name,
                        job.start_time,
                        job.end_time,
                        job.status,
                        job.instance.id,
                        job.instance.type,
                        job.instance.provider,
                        job.instance.disk.size,
                        job.instance.disk.unit,
                        job.instance.disk.type
                    ]

                    # Append the new row to the data list
                    data.append(new_row)

# Create a DataFrame from the data list
details_df = pd.DataFrame(
    data,
    columns=[
        'taskId',
        'name',
        'status',
        'project',
        'app',
        'type',
        'batch',
        'created_by',
        'executed_by',
        'start_time',
        'end_time',
        'price',
        'storage_price',
        'compute_price',
        'steps_completed',
        'system_limit',
        'account_limit',
        'instance_init',
        'steps_total',
        'message',
        'duration',
        'queued_duration',
        'running_duration',
        'execution_duration',
        'output_key',
        'output_file_id',
        'job_name',
        'job_start_time',
        'job_end_time',
        'job_status',
        'instance_id',
        'instance_type',
        'instance_provider',
        'instance_disk_size',
        'instance_disk_unit',
        'instance_disk_type'
    ]
)
details_df
# Out:
#                                     taskId  \
# 0     88426f22-bc3f-432d-926b-985c8b7fd972
# 1     88426f22-bc3f-432d-926b-985c8b7fd972
# 2     1b76b86a-6584-4a91-af69-e29886db42e9
# 3     1b76b86a-6584-4a91-af69-e29886db42e9
# 4     099b4671-e8ba-4e25-989e-406567829123
# ...                                    ...
# 3132  81e3be56-20e7-47a8-ac14-0e1e9173b5de
# 3133  fd69db5b-ac24-4c9d-8788-bcf64e3dd85f
# 3134  ab31f9d3-41f3-4ed6-9df3-745037ceee7a
# 3135  2f6bd4f0-49c0-4dc2-b905-c1e3edf05a90
# 3136  fdc9ade3-0c66-4f0e-ad77-e914d543c9d2
#
#                                                    name     status  \
# 0     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 1     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 2     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 3     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 4     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# ...                                                 ...        ...
# 3132  dcm2niix-slim-series-instance-uid-gcp-upload r...  COMPLETED
# 3133  dcm2niix-slim-series-instance-uid-gcp-upload r...  COMPLETED
# 3134   dcm2niix-slim-gcp-upload run - 01-06-23 20:25:15  COMPLETED
# 3135                   dcm2niix run - 01-05-23 19:58:33  COMPLETED
# 3136                        idc run - 01-03-23 15:24:38  COMPLETED
#
#                      project  \
# 0     vamsikrishna14/idc-gcp
# 1     vamsikrishna14/idc-gcp
# 2     vamsikrishna14/idc-gcp
# 3     vamsikrishna14/idc-gcp
# 4     vamsikrishna14/idc-gcp
# ...                      ...
# 3132      vamsikrishna14/idc
# 3133      vamsikrishna14/idc
# 3134      vamsikrishna14/idc
# 3135      vamsikrishna14/idc
# 3136      vamsikrishna14/idc
#
#                                                     app type  batch  \
# 0     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2  False
# 1     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2  False
# 2     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2  False
# 3     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2  False
# 4     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2  False
# ...                                                 ...  ...    ...
# 3132  vamsikrishna14/idc/dcm2niix-slim-gcp-upload-se...   v2  False
# 3133  vamsikrishna14/idc/dcm2niix-slim-gcp-upload-se...   v2  False
# 3134      vamsikrishna14/idc/dcm2niix-slim-gcp-upload/1   v2  False
# 3135                      vamsikrishna14/idc/dcm2niix/8   v2  False
# 3136                           vamsikrishna14/idc/idc/1   v2  False
#
#           created_by     executed_by          start_time  ...  \
# 0     vamsikrishna14  vamsikrishna14 2023-01-15 22:04:23  ...
# 1     vamsikrishna14  vamsikrishna14 2023-01-15 22:04:23  ...
# 2     vamsikrishna14  vamsikrishna14 2023-01-15 22:04:23  ...
# 3     vamsikrishna14  vamsikrishna14 2023-01-15 22:04:23  ...
# 4     vamsikrishna14  vamsikrishna14 2023-01-15 22:04:23  ...
# ...              ...             ...                 ...  ...
# 3132  vamsikrishna14  vamsikrishna14 2023-01-09 13:27:18  ...
# 3133  vamsikrishna14  vamsikrishna14 2023-01-09 13:20:01  ...
# 3134  vamsikrishna14  vamsikrishna14 2023-01-06 20:25:27  ...
# 3135  vamsikrishna14  vamsikrishna14 2023-01-05 19:59:04  ...
# 3136  vamsikrishna14  vamsikrishna14 2023-01-03 15:25:53  ...
#
#                                           job_name      job_start_time  \
# 0                      total-segmentator-cuda-prod 2023-01-15 22:10:37
# 1                      total-segmentator-cuda-prod 2023-01-15 22:10:37
# 2                      total-segmentator-cuda-prod 2023-01-15 22:10:09
# 3                      total-segmentator-cuda-prod 2023-01-15 22:10:09
# 4                      total-segmentator-cuda-prod 2023-01-15 22:10:04
# ...                                            ...                 ...
# 3132  dcm2niix-slim-gcp-upload-series-instance-uid 2023-01-09 13:29:39
# 3133  dcm2niix-slim-gcp-upload-series-instance-uid 2023-01-09 13:22:21
# 3134                      dcm2niix-slim-gcp-upload 2023-01-06 20:27:49
# 3135                                      dcm2niix 2023-01-05 20:04:03
# 3136                                           idc 2023-01-03 15:27:37
#
#             job_end_time job_status          instance_id  instance_type  \
# 0    2023-01-15 22:50:07  COMPLETED   665177423853766273  n1-standard-4
# 1    2023-01-15 22:50:07  COMPLETED   665177423853766273  n1-standard-4
# 2    2023-01-15 22:49:48  COMPLETED  6237328695009855107  n1-standard-4
# 3    2023-01-15 22:49:48  COMPLETED  6237328695009855107  n1-standard-4
# 4    2023-01-15 22:48:42  COMPLETED  7039523797290567297  n1-standard-4
# ...                  ...        ...                  ...            ...
# 3132 2023-01-09 13:29:54  COMPLETED  i-02a6620107f8dca69       c5.large
# 3133 2023-01-09 13:22:36  COMPLETED  i-03ad535f66d4586b4       c5.large
# 3134 2023-01-06 20:28:25  COMPLETED  i-0ba00a2a10a5de422       c5.large
# 3135 2023-01-05 20:04:29  COMPLETED  i-0a828cc8ac84b2b99       c5.large
# 3136 2023-01-03 15:28:12  COMPLETED  i-002e85871b33bdffb     c4.2xlarge
#
#       instance_provider  instance_disk_size  instance_disk_unit  \
# 0                   GCP                1024                  GB
# 1                   GCP                1024                  GB
# 2                   GCP                1024                  GB
# 3                   GCP                1024                  GB
# 4                   GCP                1024                  GB
# ...                 ...                 ...                 ...
# 3132                AWS                 100                  GB
# 3133                AWS                 100                  GB
# 3134                AWS                 100                  GB
# 3135                AWS                 100                  GB
# 3136                AWS                1024                  GB
#
#      instance_disk_type
# 0                pd-ssd
# 1                pd-ssd
# 2                pd-ssd
# 3                pd-ssd
# 4                pd-ssd
# ...                 ...
# 3132            ebs-gp2
# 3133            ebs-gp2
# 3134            ebs-gp2
# 3135            ebs-gp2
# 3136            ebs-gp2
#
# [3137 rows x 36 columns]

# %%
final_detailed_task_df = pd.merge(final_task_df, details_df, on='taskId', how='left').drop_duplicates().reset_index(drop=True)
final_detailed_task_df
# Out:
#                                    batchId               projectId  batch_x  \
# 0     51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp     True
# 1     51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp     True
# 2     51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp     True
# 3     51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp     True
# 4     51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp     True
# ...                                    ...                     ...      ...
# 3138                                            vamsikrishna14/idc    False
# 3139                                            vamsikrishna14/idc    False
# 3140                                            vamsikrishna14/idc    False
# 3141                                            vamsikrishna14/idc    False
# 3142                                            vamsikrishna14/idc    False
#
#                                     taskId  \
# 0     88426f22-bc3f-432d-926b-985c8b7fd972
# 1     88426f22-bc3f-432d-926b-985c8b7fd972
# 2     1b76b86a-6584-4a91-af69-e29886db42e9
# 3     1b76b86a-6584-4a91-af69-e29886db42e9
# 4     099b4671-e8ba-4e25-989e-406567829123
# ...                                    ...
# 3138  ab31f9d3-41f3-4ed6-9df3-745037ceee7a
# 3139  2f6bd4f0-49c0-4dc2-b905-c1e3edf05a90
# 3140  0dcc6b33-5c51-43f3-b90d-0052229052fe
# 3141  14b442d2-5d99-4162-bb49-833eed086a89
# 3142  fdc9ade3-0c66-4f0e-ad77-e914d543c9d2
#
#                                                    name     status  \
# 0     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 1     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 2     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 3     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 4     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# ...                                                 ...        ...
# 3138   dcm2niix-slim-gcp-upload run - 01-06-23 20:25:15  COMPLETED
# 3139                   dcm2niix run - 01-05-23 19:58:33  COMPLETED
# 3140                                                NaN        NaN
# 3141                                                NaN        NaN
# 3142                        idc run - 01-03-23 15:24:38  COMPLETED
#
#                      project  \
# 0     vamsikrishna14/idc-gcp
# 1     vamsikrishna14/idc-gcp
# 2     vamsikrishna14/idc-gcp
# 3     vamsikrishna14/idc-gcp
# 4     vamsikrishna14/idc-gcp
# ...                      ...
# 3138      vamsikrishna14/idc
# 3139      vamsikrishna14/idc
# 3140                     NaN
# 3141                     NaN
# 3142      vamsikrishna14/idc
#
#                                                     app type batch_y  ...  \
# 0     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2   False  ...
# 1     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2   False  ...
# 2     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2   False  ...
# 3     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2   False  ...
# 4     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2   False  ...
# ...                                                 ...  ...     ...  ...
# 3138      vamsikrishna14/idc/dcm2niix-slim-gcp-upload/1   v2   False  ...
# 3139                      vamsikrishna14/idc/dcm2niix/8   v2   False  ...
# 3140                                                NaN  NaN     NaN  ...
# 3141                                                NaN  NaN     NaN  ...
# 3142                           vamsikrishna14/idc/idc/1   v2   False  ...
#
#                          job_name      job_start_time        job_end_time  \
# 0     total-segmentator-cuda-prod 2023-01-15 22:10:37 2023-01-15 22:50:07
# 1     total-segmentator-cuda-prod 2023-01-15 22:10:37 2023-01-15 22:50:07
# 2     total-segmentator-cuda-prod 2023-01-15 22:10:09 2023-01-15 22:49:48
# 3     total-segmentator-cuda-prod 2023-01-15 22:10:09 2023-01-15 22:49:48
# 4     total-segmentator-cuda-prod 2023-01-15 22:10:04 2023-01-15 22:48:42
# ...                           ...                 ...                 ...
# 3138     dcm2niix-slim-gcp-upload 2023-01-06 20:27:49 2023-01-06 20:28:25
# 3139                     dcm2niix 2023-01-05 20:04:03 2023-01-05 20:04:29
# 3140                          NaN                 NaT                 NaT
# 3141                          NaN                 NaT                 NaT
# 3142                          idc 2023-01-03 15:27:37 2023-01-03 15:28:12
#
#      job_status          instance_id  instance_type instance_provider  \
# 0     COMPLETED   665177423853766273  n1-standard-4               GCP
# 1     COMPLETED   665177423853766273  n1-standard-4               GCP
# 2     COMPLETED  6237328695009855107  n1-standard-4               GCP
# 3     COMPLETED  6237328695009855107  n1-standard-4               GCP
# 4     COMPLETED  7039523797290567297  n1-standard-4               GCP
# ...         ...                  ...            ...               ...
# 3138  COMPLETED  i-0ba00a2a10a5de422       c5.large               AWS
# 3139  COMPLETED  i-0a828cc8ac84b2b99       c5.large               AWS
# 3140        NaN                  NaN            NaN               NaN
# 3141        NaN                  NaN            NaN               NaN
# 3142  COMPLETED  i-002e85871b33bdffb     c4.2xlarge               AWS
#
#       instance_disk_size instance_disk_unit instance_disk_type
# 0                 1024.0                 GB             pd-ssd
# 1                 1024.0                 GB             pd-ssd
# 2                 1024.0                 GB             pd-ssd
# 3                 1024.0                 GB             pd-ssd
# 4                 1024.0                 GB             pd-ssd
# ...                  ...                ...                ...
# 3138               100.0                 GB            ebs-gp2
# 3139               100.0                 GB            ebs-gp2
# 3140                 NaN                NaN                NaN
# 3141                 NaN                NaN                NaN
# 3142              1024.0                 GB            ebs-gp2
#
# [3143 rows x 39 columns]

# %%
import time

outputFiles = final_detailed_task_df['output_file_id'].to_list()
# Get unique list of output files
unique_output_files = list(set(outputFiles))
time.sleep(5.5 * 60)
# Iterate over unique list and populate dataframe
for file in unique_output_files:
    try:
        fileInfo = api.files.get(file)
        name = fileInfo.name
        url = fileInfo.download_info().url
        
        # Find all rows with the current file ID and populate with file name and URL
        final_detailed_task_df.loc[final_detailed_task_df['output_file_id'] == file, 'file_name'] = name
        final_detailed_task_df.loc[final_detailed_task_df['output_file_id'] == file, 'file_url'] = url
        
    except Exception as e:
        print(f'Error retrieving file {file}: {e}')
    
    if (unique_output_files.index(file) + 1) % 500 == 0:
        time.sleep(5.5 * 60)
final_detailed_task_df

# %%
final_detailed_task_df
# Out:
#                                    batchId               projectId  batch_x  \
# 0     51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp     True
# 1     51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp     True
# 2     51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp     True
# 3     51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp     True
# 4     51e318d3-618b-49e7-9d0d-81b4e7c93b1a  vamsikrishna14/idc-gcp     True
# ...                                    ...                     ...      ...
# 3138                                            vamsikrishna14/idc    False
# 3139                                            vamsikrishna14/idc    False
# 3140                                            vamsikrishna14/idc    False
# 3141                                            vamsikrishna14/idc    False
# 3142                                            vamsikrishna14/idc    False
#
#                                     taskId  \
# 0     88426f22-bc3f-432d-926b-985c8b7fd972
# 1     88426f22-bc3f-432d-926b-985c8b7fd972
# 2     1b76b86a-6584-4a91-af69-e29886db42e9
# 3     1b76b86a-6584-4a91-af69-e29886db42e9
# 4     099b4671-e8ba-4e25-989e-406567829123
# ...                                    ...
# 3138  ab31f9d3-41f3-4ed6-9df3-745037ceee7a
# 3139  2f6bd4f0-49c0-4dc2-b905-c1e3edf05a90
# 3140  0dcc6b33-5c51-43f3-b90d-0052229052fe
# 3141  14b442d2-5d99-4162-bb49-833eed086a89
# 3142  fdc9ade3-0c66-4f0e-ad77-e914d543c9d2
#
#                                                    name     status  \
# 0     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 1     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 2     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 3     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# 4     total-segmentator-cuda-prod run - 01-15-23 21:...  COMPLETED
# ...                                                 ...        ...
# 3138   dcm2niix-slim-gcp-upload run - 01-06-23 20:25:15  COMPLETED
# 3139                   dcm2niix run - 01-05-23 19:58:33  COMPLETED
# 3140                                                NaN        NaN
# 3141                                                NaN        NaN
# 3142                        idc run - 01-03-23 15:24:38  COMPLETED
#
#                      project  \
# 0     vamsikrishna14/idc-gcp
# 1     vamsikrishna14/idc-gcp
# 2     vamsikrishna14/idc-gcp
# 3     vamsikrishna14/idc-gcp
# 4     vamsikrishna14/idc-gcp
# ...                      ...
# 3138      vamsikrishna14/idc
# 3139      vamsikrishna14/idc
# 3140                     NaN
# 3141                     NaN
# 3142      vamsikrishna14/idc
#
#                                                     app type batch_y  ...  \
# 0     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2   False  ...
# 1     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2   False  ...
# 2     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2   False  ...
# 3     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2   False  ...
# 4     vamsikrishna14/idc-gcp/total-segmentator-cuda-...   v2   False  ...
# ...                                                 ...  ...     ...  ...
# 3138      vamsikrishna14/idc/dcm2niix-slim-gcp-upload/1   v2   False  ...
# 3139                      vamsikrishna14/idc/dcm2niix/8   v2   False  ...
# 3140                                                NaN  NaN     NaN  ...
# 3141                                                NaN  NaN     NaN  ...
# 3142                           vamsikrishna14/idc/idc/1   v2   False  ...
#
#             job_end_time job_status          instance_id  instance_type  \
# 0    2023-01-15 22:50:07  COMPLETED   665177423853766273  n1-standard-4
# 1    2023-01-15 22:50:07  COMPLETED   665177423853766273  n1-standard-4
# 2    2023-01-15 22:49:48  COMPLETED  6237328695009855107  n1-standard-4
# 3    2023-01-15 22:49:48  COMPLETED  6237328695009855107  n1-standard-4
# 4    2023-01-15 22:48:42  COMPLETED  7039523797290567297  n1-standard-4
# ...                  ...        ...                  ...            ...
# 3138 2023-01-06 20:28:25  COMPLETED  i-0ba00a2a10a5de422       c5.large
# 3139 2023-01-05 20:04:29  COMPLETED  i-0a828cc8ac84b2b99       c5.large
# 3140                 NaT        NaN                  NaN            NaN
# 3141                 NaT        NaN                  NaN            NaN
# 3142 2023-01-03 15:28:12  COMPLETED  i-002e85871b33bdffb     c4.2xlarge
#
#       instance_provider instance_disk_size instance_disk_unit  \
# 0                   GCP             1024.0                 GB
# 1                   GCP             1024.0                 GB
# 2                   GCP             1024.0                 GB
# 3                   GCP             1024.0                 GB
# 4                   GCP             1024.0                 GB
# ...                 ...                ...                ...
# 3138                AWS              100.0                 GB
# 3139                AWS              100.0                 GB
# 3140                NaN                NaN                NaN
# 3141                NaN                NaN                NaN
# 3142                AWS             1024.0                 GB
#
#       instance_disk_type                                          file_name  \
# 0                 pd-ssd  _7_1.2.840.113654.2.55.18071186844659945894242...
# 1                 pd-ssd  _7_1.2.840.113654.2.55.18071186844659945894242...
# 2                 pd-ssd  _7_1.2.840.113654.2.55.19159417322957993171143...
# 3                 pd-ssd  _7_1.2.840.113654.2.55.19159417322957993171143...
# 4                 pd-ssd  _7_1.2.840.113654.2.55.20041484433454014774677...
# ...                  ...                                                ...
# 3138             ebs-gp2
# 3139             ebs-gp2
# 3140                 NaN
# 3141                 NaN
# 3142             ebs-gp2
#
#                                                file_url
# 0     https://storage.googleapis.com/cgc-main-us-wes...
# 1     https://storage.googleapis.com/cgc-main-us-wes...
# 2     https://storage.googleapis.com/cgc-main-us-wes...
# 3     https://storage.googleapis.com/cgc-main-us-wes...
# 4     https://storage.googleapis.com/cgc-main-us-wes...
# ...                                                 ...
# 3138
# 3139
# 3140
# 3141
# 3142
#
# [3143 rows x 41 columns]

# %%
final_detailed_task_df.to_csv('final.csv')
